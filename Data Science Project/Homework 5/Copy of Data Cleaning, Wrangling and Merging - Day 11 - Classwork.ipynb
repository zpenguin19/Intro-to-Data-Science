# %% [markdown]
# # Dataset
#
# #### Overview:
# > **From the CORGIS Dataset Project**: "The following data contains records collected on different countries and geographic locations from 1980 - 2013 from the World Bank. Included is different data about urban development, agriculture and rural development, health, and infrastructure."
#
# In this section, we will work through examples using data from the [Museum of Modern Art (MoMA) research dataset](https://github.com/MuseumofModernArt/collection) containing records of all of the works that have been cataloged in the database of the MoMA collection.
#
# > "The Museum’s website features 89,695 artworks from 26,494 artists. This research dataset contains 138,151 records, representing all of the works that have been accessioned into MoMA’s collection and cataloged in our database. It includes basic metadata for each work, including title, artist, date made, medium, dimensions, and date acquired by the Museum. Some of these records have incomplete information and are noted as “not Curator Approved." - [MoMA Github repository for collection data](https://github.com/MuseumofModernArt/collection)
#
# We have prepared a dataset that consists of a subset of MoMA artworks classified as paintings and their associated artist information to use in the following activities. We will be referencing the data that we have prepared in our [Github repository for teaching datasets](https://github.com/ncsu-libraries-data-vis/teaching-datasets/tree/main/moma_data).
#
# If you haven't chosen a dataset yet, use the datasets below.
#
#
#
# The links our datasets are sourced from:
# https://corgis-edu.github.io/corgis/csv/global_development/
#
# https://corgis-edu.github.io/corgis/csv/global_emissions/

# %%
#import pandas
import pandas as pd

# %%
# Import the MoMA paintings dataset (CSV file)
# The file location

# Read in the file and print out the DataFrame
development_df = pd.read_csv('/content/global_development.csv')
development_df
# Out:
#                                      Country  Year  Data.Health.Birth Rate  \
# 0                                     Canada  1980               15.400000
# 1                                     Canada  1981               15.400000
# 2                                     Canada  1982               15.300000
# 3                                     Canada  1983               15.100000
# 4                                     Canada  1984               15.000000
# ...                                      ...   ...                     ...
# 6421  Heavily indebted poor countries (HIPC)  2009               39.694362
# 6422  Heavily indebted poor countries (HIPC)  2010               39.249875
# 6423  Heavily indebted poor countries (HIPC)  2011               38.807293
# 6424  Heavily indebted poor countries (HIPC)  2012               38.366140
# 6425  Heavily indebted poor countries (HIPC)  2013               37.924698
#
#       Data.Health.Death Rate  Data.Health.Fertility Rate  \
# 0                   7.000000                    1.754000
# 1                   7.100000                    1.740000
# 2                   7.000000                    1.700000
# 3                   7.100000                    1.690000
# 4                   7.000000                    1.680000
# ...                      ...                         ...
# 6421               11.568275                    5.448853
# 6422               11.239563                    5.363884
# 6423               10.936774                    5.278963
# 6424               10.661019                    5.194085
# 6425               10.407943                    5.109213
#
#       Data.Health.Life Expectancy at Birth, Female  \
# 0                                        78.590000
# 1                                        78.730000
# 2                                        79.110000
# 3                                        79.230000
# 4                                        79.550000
# ...                                            ...
# 6421                                     57.314810
# 6422                                     57.941917
# 6423                                     58.533726
# 6424                                     59.080577
# 6425                                     59.585337
#
#       Data.Health.Life Expectancy at Birth, Male  \
# 0                                      71.320000
# 1                                      71.600000
# 2                                      72.020000
# 3                                      72.300000
# 4                                      72.690000
# ...                                          ...
# 6421                                   55.042182
# 6422                                   55.580622
# 6423                                   56.080300
# 6424                                   56.538581
# 6425                                   56.962692
#
#       Data.Health.Life Expectancy at Birth, Total  \
# 0                                       74.866341
# 1                                       75.078049
# 2                                       75.478537
# 3                                       75.680488
# 4                                       76.036341
# ...                                           ...
# 6421                                    56.149510
# 6422                                    56.731231
# 6423                                    57.275881
# 6424                                    57.777390
# 6425                                    58.240852
#
#       Data.Health.Population Growth  Data.Health.Total Population  ...  \
# 0                          0.997669                    24277000.0  ...
# 1                          1.293245                    24593000.0  ...
# 2                          1.240595                    24900000.0  ...
# 3                          1.205555                    25202000.0  ...
# 4                          1.002812                    25456000.0  ...
# ...                             ...                           ...  ...
# 6421                       2.755547                   589184942.0  ...
# 6422                       2.742284                   605342064.0  ...
# 6423                       2.728734                   621860240.0  ...
# 6424                       2.714024                   638737676.0  ...
# 6425                       2.698148                   655971763.0  ...
#
#       Data.Rural Development.Agricultural Land Percent  \
# 0                                             7.357225
# 1                                             7.301471
# 2                                             7.245717
# 3                                             7.288275
# 4                                             7.330943
# ...                                                ...
# 6421                                         40.224998
# 6422                                         40.282701
# 6423                                         40.402744
# 6424                                         39.072643
# 6425                                         39.676293
#
#       Data.Rural Development.Arable Land  \
# 0                               1.827821
# 1                               1.818526
# 2                               1.810120
# 3                               1.789779
# 4                               1.773217
# ...                                  ...
# 6421                            0.259585
# 6422                            0.254637
# 6423                            0.251078
# 6424                            0.243605
# 6425                            0.253896
#
#       Data.Rural Development.Arable Land Percent  \
# 0                                       4.879744
# 1                                       4.918123
# 2                                       4.956502
# 3                                       4.960241
# 4                                       4.963870
# ...                                          ...
# 6421                                    7.742953
# 6422                                    7.803635
# 6423                                    7.904542
# 6424                                    7.877416
# 6425                                    8.431096
#
#       Data.Rural Development.Land Area  \
# 0                            9093510.0
# 1                            9093510.0
# 2                            9093510.0
# 3                            9093510.0
# 4                            9093510.0
# ...                                ...
# 6421                        19752631.0
# 6422                        19752631.0
# 6423                        19752631.0
# 6424                        19752631.0
# 6425                        19754076.0
#
#       Data.Rural Development.Rural Population  \
# 0                                     5918004
# 1                                     5985198
# 2                                     6047712
# 3                                     6080235
# 4                                     6100530
# ...                                       ...
# 6421                                404203594
# 6422                                412723475
# 6423                                421313384
# 6424                                429969441
# 6425                                438680058
#
#       Data.Rural Development.Rural Population Growth  \
# 0                                           0.833712
# 1                                           1.129019
# 2                                           1.039060
# 3                                           0.536333
# 4                                           0.333231
# ...                                              ...
# 6421                                        2.132400
# 6422                                        2.107819
# 6423                                        2.081275
# 6424                                        2.054541
# 6425                                        2.025869
#
#       Data.Rural Development.Surface Area  \
# 0                               9984670.0
# 1                               9984670.0
# 2                               9984670.0
# 3                               9984670.0
# 4                               9984670.0
# ...                                   ...
# 6421                           20392171.0
# 6422                           20392171.0
# 6423                           20392171.0
# 6424                           19765718.5
# 6425                           19767153.5
#
#       Data.Urban Development.Population Density  \
# 0                                      2.669706
# 1                                      2.704456
# 2                                      2.738217
# 3                                      2.771427
# 4                                      2.799359
# ...                                         ...
# 6421                                  29.828175
# 6422                                  30.646149
# 6423                                  31.482400
# 6424                                  32.336840
# 6425                                  33.206907
#
#       Data.Urban Development.Urban Population Percent  \
# 0                                           75.623000
# 1                                           75.663000
# 2                                           75.712000
# 3                                           75.874000
# 4                                           76.035000
# ...                                               ...
# 6421                                        31.396143
# 6422                                        31.819793
# 6423                                        32.249506
# 6424                                        32.684503
# 6425                                        33.125161
#
#       Data.Urban Development.Urban Population Percent Growth
# 0                                              1.050578
# 1                                              1.346126
# 2                                              1.305333
# 3                                              1.419293
# 4                                              1.214785
# ...                                                 ...
# 6421                                           4.144006
# 6422                                           4.128655
# 6423                                           4.116045
# 6424                                           4.099480
# 6425                                           4.082743
#
# [6426 rows x 25 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 1.Data Cleaning

# %% [markdown]
# ## 1.1 Get to know data
#
# > #### Data description:
# - `Country` - the name of the country that the data is taken from
# - `Year` - the year the data of a country is taken from
# - `Data.Health.Birth Rate` - the birth rate for the particular country and year
# - `Data.Health.Death Rate` - the death rate for the particular country and year
# - `Data.Health.Fertility Rate` - the fertility rate for the particular country and year
# - `Data.Health.Life Expectancy at Birth, Female` - the life expectancy of a female born in the particular country and year
# - `Data.Health.Life Expectancy at Birth, Male` - the life expectancy of a male born in the particular country and year
# - `Data.Health.Life Expectancy at Birth, Total`	- the life expectancy for someone born in the particular country and year
# - `Data.Health.Population Growth` - the population growth of the country in that year
# - `Data.Health.Total Population` - the total population of the particular country in the specified year
# - `Data.Infrastructure.Mobile Cellular Subscriptions` - the total number of cell phone subscriptions in the particular country and year
# - `Data.Infrastructure.Mobile Cellular Subscriptions per 100 People` - the number of cell phone subscriptions per 100 people in the particular country and year
# - `Data.Infrastructure.Telephone Lines` - the total number of telephone lines in the particular country and year
# - `Data.Infrastructure.Telephone Lines per 100 People` - the number of telephone lines per 100 people in the particular country and year
# - `Data.Rural Development.Agricultural Land` - total area of agricultural land in the particular country and year
# - `Data.Rural Development.Agricultural Land Percent` - percent of the country's land that is used for agriculture in the given year
# - `Data.Rural Development.Arable Land` - total area of arable land in the particular country and year
# - `Data.Rural Development.Arable Land Percent` - percent of the country's land that is arable in the given year
# - `Data.Rural Development.Land Area` - total area of rural land in the particular country and year
# - `Data.Rural Development.Rural Population` - number of people living in rural areas in the particular country and year
# - `Data.Rural Development.Rural Population Growth` - the population growth of rural areas in the particular country in that year
# - `Data.Rural Development.Surface Area` - surface area of rural areas in the particular country and year
# - `Data.Urban Development.Population Density` - density of people living in urban areas in the particular country and year
# - `Data.Urban Development.Urban Population Percent` - percent of the population that lives in urban areas in the given country and year
# - `Data.Urban Development.Urban Population Percent Growth` - the population growth of urban areas in the particular country in that year
#
# The data dictionary:
#
# - 'Index': value given as the artwork was catelogued, unique for every piece
# - 'Title': Title for the artwork, can overlap with other paintings
# - 'Artist': The name of the artist
# - 'ConstituentID': unique artist ID
# - 'Date': Date the artwork is known to be painted
# - 'Medium': Details about the medium used to paint the artwork
# - 'Dimensions': Dimensions of the artwork
# - 'CreditLine': How was this artwork acquired
# - 'AccessionNumber': ID unique for each piece in MoMA
# - 'Classification': Denotes the type of artwork
# - 'Department': Department name
# - 'DateAcquired': Date the painting was acquired by MoMA
# - 'Cataloged': If the painting has been catelogued
# - 'ObjectID': ID for the peice
# - 'URL': URL for image
# - 'ThumbnailURL': URL for the thumbnail
# - 'Circumference (cm)': Circumference of the artwork
# - 'Depth (cm)': Depth of the artwork
# - 'Diameter (cm)': Diameter of the artwork
# - 'Height (cm)': Height of the artwork
# - 'Length (cm)': Length of the artwork
# - 'Weight (kg)': Weight of the artwork
# - 'Width (cm)': Width of the artwork
# - 'Seat Height (cm)': Height of the seat near the artwork
# - 'Duration (sec.)': Duration permissable for viewing in seconds

# %%
# find shape of the data

print(f"Shape of global development: {development_df.shape}")
# Out:
# Shape of global development: (6426, 25)

# %%
# print columns labels

print(f"Columns of global development:\n {development_df.columns}")
# Out:
# Columns of global development:
#  Index(['Country', 'Year', 'Data.Health.Birth Rate', 'Data.Health.Death Rate',
#        'Data.Health.Fertility Rate',
#        'Data.Health.Life Expectancy at Birth, Female',
#        'Data.Health.Life Expectancy at Birth, Male',
#        'Data.Health.Life Expectancy at Birth, Total',
#        'Data.Health.Population Growth', 'Data.Health.Total Population',
#        'Data.Infrastructure.Mobile Cellular Subscriptions',
#        'Data.Infrastructure.Mobile Cellular Subscriptions per 100 People',
#        'Data.Infrastructure.Telephone Lines',
#        'Data.Infrastructure.Telephone Lines per 100 People',
#        'Data.Rural Development.Agricultural Land',
#        'Data.Rural Development.Agricultural Land Percent',
#        'Data.Rural Development.Arable Land',
#        'Data.Rural Development.Arable Land Percent',
#        'Data.Rural Development.Land Area',
#        'Data.Rural Development.Rural Population',
#        'Data.Rural Development.Rural Population Growth',
#        'Data.Rural Development.Surface Area',
#        'Data.Urban Development.Population Density',
#        'Data.Urban Development.Urban Population Percent',
#        'Data.Urban Development.Urban Population Percent Growth'],
#       dtype='object')

# %%
# check row labels
print(f"Row labels of global development: {development_df.index}")
# Out:
# Row labels of global development: RangeIndex(start=0, stop=6426, step=1)

# %%
# find the column that is unique to each row (unit of observation)
# HINT: these will have number of unique values equal to the number of rows in the dataframe
# could be names or IDs
print(len(development_df["Country"].unique()))
len(development_df["Year"].unique())
# Out:
# 189
# 54

# %%
# check type of varaibles
development_df.dtypes
# Out:
# Country                                                              object
# Year                                                                  int64
# Data.Health.Birth Rate                                              float64
# Data.Health.Death Rate                                              float64
# Data.Health.Fertility Rate                                          float64
# Data.Health.Life Expectancy at Birth, Female                        float64
# Data.Health.Life Expectancy at Birth, Male                          float64
# Data.Health.Life Expectancy at Birth, Total                         float64
# Data.Health.Population Growth                                       float64
# Data.Health.Total Population                                        float64
# Data.Infrastructure.Mobile Cellular Subscriptions                   float64
# Data.Infrastructure.Mobile Cellular Subscriptions per 100 People    float64
# Data.Infrastructure.Telephone Lines                                 float64
# Data.Infrastructure.Telephone Lines per 100 People                  float64
# Data.Rural Development.Agricultural Land                            float64
# Data.Rural Development.Agricultural Land Percent                    float64
# Data.Rural Development.Arable Land                                  float64
# Data.Rural Development.Arable Land Percent                          float64
# Data.Rural Development.Land Area                                    float64
# Data.Rural Development.Rural Population                               int64
# Data.Rural Development.Rural Population Growth                      float64
# Data.Rural Development.Surface Area                                 float64
# Data.Urban Development.Population Density                           float64
# Data.Urban Development.Urban Population Percent                     float64
# Data.Urban Development.Urban Population Percent Growth              float64
# dtype: object

# %% [markdown]
# Strings are usually represented as objects, check few rows to learn more about objects. They could also be compound data types like lists and dictionaries within a column - that may need more cleaning.
#
# You can find the datatype of a column through `dtype` attribute

# %%
# similarly to know the datatype of a single column in the dataframe
# HINT: use dtype
development_df["Year"].dtype
# Out:
# dtype('int64')

# %%
# display the head
development_df.head()
# Out:
#   Country  Year  Data.Health.Birth Rate  Data.Health.Death Rate  \
# 0  Canada  1980                    15.4                     7.0
# 1  Canada  1981                    15.4                     7.1
# 2  Canada  1982                    15.3                     7.0
# 3  Canada  1983                    15.1                     7.1
# 4  Canada  1984                    15.0                     7.0
#
#    Data.Health.Fertility Rate  Data.Health.Life Expectancy at Birth, Female  \
# 0                       1.754                                         78.59
# 1                       1.740                                         78.73
# 2                       1.700                                         79.11
# 3                       1.690                                         79.23
# 4                       1.680                                         79.55
#
#    Data.Health.Life Expectancy at Birth, Male  \
# 0                                       71.32
# 1                                       71.60
# 2                                       72.02
# 3                                       72.30
# 4                                       72.69
#
#    Data.Health.Life Expectancy at Birth, Total  Data.Health.Population Growth  \
# 0                                    74.866341                       0.997669
# 1                                    75.078049                       1.293245
# 2                                    75.478537                       1.240595
# 3                                    75.680488                       1.205555
# 4                                    76.036341                       1.002812
#
#    Data.Health.Total Population  ...  \
# 0                    24277000.0  ...
# 1                    24593000.0  ...
# 2                    24900000.0  ...
# 3                    25202000.0  ...
# 4                    25456000.0  ...
#
#    Data.Rural Development.Agricultural Land Percent  \
# 0                                          7.357225
# 1                                          7.301471
# 2                                          7.245717
# 3                                          7.288275
# 4                                          7.330943
#
#    Data.Rural Development.Arable Land  \
# 0                            1.827821
# 1                            1.818526
# 2                            1.810120
# 3                            1.789779
# 4                            1.773217
#
#    Data.Rural Development.Arable Land Percent  \
# 0                                    4.879744
# 1                                    4.918123
# 2                                    4.956502
# 3                                    4.960241
# 4                                    4.963870
#
#    Data.Rural Development.Land Area  Data.Rural Development.Rural Population  \
# 0                         9093510.0                                  5918004
# 1                         9093510.0                                  5985198
# 2                         9093510.0                                  6047712
# 3                         9093510.0                                  6080235
# 4                         9093510.0                                  6100530
#
#    Data.Rural Development.Rural Population Growth  \
# 0                                        0.833712
# 1                                        1.129019
# 2                                        1.039060
# 3                                        0.536333
# 4                                        0.333231
#
#    Data.Rural Development.Surface Area  \
# 0                            9984670.0
# 1                            9984670.0
# 2                            9984670.0
# 3                            9984670.0
# 4                            9984670.0
#
#    Data.Urban Development.Population Density  \
# 0                                   2.669706
# 1                                   2.704456
# 2                                   2.738217
# 3                                   2.771427
# 4                                   2.799359
#
#    Data.Urban Development.Urban Population Percent  \
# 0                                           75.623
# 1                                           75.663
# 2                                           75.712
# 3                                           75.874
# 4                                           76.035
#
#    Data.Urban Development.Urban Population Percent Growth
# 0                                           1.050578
# 1                                           1.346126
# 2                                           1.305333
# 3                                           1.419293
# 4                                           1.214785
#
# [5 rows x 25 columns]

# %% [markdown]
# ## 1.2 Identify which numerical columns and categorical columns

# %% [markdown]
# ## Document!!!
#
# Usually a good idea to mark which columns you think and find to be categorical.
#
# For the paintings dataset - check
# Mark which columns should be what in this data dictionary
#
# - 'Index': ID for each piece
# - 'Title': Title for the artwork, can overlap with other paintings
# - 'Artist': The name of the artist
# - 'ConstituentID': ID of a theme
# - 'Date': Date the artwork is known to be painted
# - 'Medium': Details about the medium used to paint the artwork
# - 'Dimensions': Dimensions of the artwork
# - 'CreditLine': How was this artwork acquired
# - 'AccessionNumber': a unique number assigned to an item or record in a MoMA database
# - 'Classification': Denotes the type of artwork
# - 'Department': Department name
# - 'DateAcquired': Date the painting was acquired by MoMA
# - 'Cataloged': If the painting has been catelogued
# - 'ObjectID': ID for the peice
# - 'URL': URL for image
# - 'ThumbnailURL': URL for the thumbnail
# - 'Circumference (cm)': Circumference of the artwork
# - 'Depth (cm)': Depth of the artwork
# - 'Diameter (cm)': Diameter of the artwork
# - 'Height (cm)': Height of the artwork
# - 'Length (cm)': Length of the artwork
# - 'Weight (kg)': Weight of the artwork
# - 'Width (cm)': Width of the artwork
# - 'Seat Height (cm)': Height of the seat near the artwork
# - 'Duration (sec.)': Duration permissable for viewing in seconds

# %%
# create a list of the columns that are categorical and those that are integer and those that have string values

import numpy as np
numerical = []
categorical = []
string = []

for column in development_df.columns:
  if development_df[column].nunique() < 10:
    categorical.append(column)
  elif development_df[column].dtype == np.float64 or development_df[column].dtype == np.int64:
   numerical.append(column)
  else:
    string.append(column)

print("Numerical columns: ", numerical)
print("Categorical columns: ", categorical)
print("String columns: ", string)
# Out:
# Numerical columns:  ['Year', 'Data.Health.Birth Rate', 'Data.Health.Death Rate', 'Data.Health.Fertility Rate', 'Data.Health.Life Expectancy at Birth, Female', 'Data.Health.Life Expectancy at Birth, Male', 'Data.Health.Life Expectancy at Birth, Total', 'Data.Health.Population Growth', 'Data.Health.Total Population', 'Data.Infrastructure.Mobile Cellular Subscriptions', 'Data.Infrastructure.Mobile Cellular Subscriptions per 100 People', 'Data.Infrastructure.Telephone Lines', 'Data.Infrastructure.Telephone Lines per 100 People', 'Data.Rural Development.Agricultural Land', 'Data.Rural Development.Agricultural Land Percent', 'Data.Rural Development.Arable Land', 'Data.Rural Development.Arable Land Percent', 'Data.Rural Development.Land Area', 'Data.Rural Development.Rural Population', 'Data.Rural Development.Rural Population Growth', 'Data.Rural Development.Surface Area', 'Data.Urban Development.Population Density', 'Data.Urban Development.Urban Population Percent', 'Data.Urban Development.Urban Population Percent Growth']
# Categorical columns:  []
# String columns:  ['Country']

# %% [markdown]
# Why were numerical columns put into categorical bin?

# %% [markdown]
# But categorical columns are not coded as cetagorical - let's fix that.

# %% [markdown]
# ### 1.2.1 Categorical columns coding
#
# Sometimes you need some categorical columns to be numbers, or encoded as numbers.

# %%
# convert all the columns in the categorical list to be of the type category

development_df["Country"] = development_df["Country"].astype('category')

development_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6426 entries, 0 to 6425
# Data columns (total 25 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Country                                                           6426 non-null   category
#  1   Year                                                              6426 non-null   int64
#  2   Data.Health.Birth Rate                                            6426 non-null   float64
#  3   Data.Health.Death Rate                                            6426 non-null   float64
#  4   Data.Health.Fertility Rate                                        6426 non-null   float64
#  5   Data.Health.Life Expectancy at Birth, Female                      6426 non-null   float64
#  6   Data.Health.Life Expectancy at Birth, Male                        6426 non-null   float64
#  7   Data.Health.Life Expectancy at Birth, Total                       6426 non-null   float64
#  8   Data.Health.Population Growth                                     6426 non-null   float64
#  9   Data.Health.Total Population                                      6426 non-null   float64
#  10  Data.Infrastructure.Mobile Cellular Subscriptions                 6426 non-null   float64
#  11  Data.Infrastructure.Mobile Cellular Subscriptions per 100 People  6426 non-null   float64
#  12  Data.Infrastructure.Telephone Lines                               6426 non-null   float64
#  13  Data.Infrastructure.Telephone Lines per 100 People                6426 non-null   float64
#  14  Data.Rural Development.Agricultural Land                          6426 non-null   float64
#  15  Data.Rural Development.Agricultural Land Percent                  6426 non-null   float64
#  16  Data.Rural Development.Arable Land                                6426 non-null   float64
#  17  Data.Rural Development.Arable Land Percent                        6426 non-null   float64
#  18  Data.Rural Development.Land Area                                  6426 non-null   float64
#  19  Data.Rural Development.Rural Population                           6426 non-null   int64
#  20  Data.Rural Development.Rural Population Growth                    6426 non-null   float64
#  21  Data.Rural Development.Surface Area                               6426 non-null   float64
#  22  Data.Urban Development.Population Density                         6426 non-null   float64
#  23  Data.Urban Development.Urban Population Percent                   6426 non-null   float64
#  24  Data.Urban Development.Urban Population Percent Growth            6426 non-null   float64
# dtypes: category(1), float64(22), int64(2)
# memory usage: 1.2 MB

# %% [markdown]
# Most of the commands shown until this point, you would have used in your homework assignment 4.

# %% [markdown]
# ### 1.2.2. Numerical column consistency

# %%
# We have multiple ID columns, check formats
# ConstitutentID should be an Integer but is currently represented as a Float with .0
#paintings['ConstituentID'] = paintings['ConstituentID'].astype(int)

# development_df['Data.Rural Development.Agricultural Land'] = development_df['Data.Rural Development.Agricultural Land'].astype('Int64')

# development_df["Data.Rural Development.Agricultural Land"].head()

# %% [markdown]
# What is the difference between int and Int?

# %% [markdown]
# ### 1.2.3 Working with date and time columns

# %% [markdown]
# Our MoMA dataset contains some columns of data that represent date values (for example, `DateAcquired`,  `Date`). Currently, each of these columns is recognized as strings (the pandas object datatype). If we look at the `DateAcquired` column we see that it contains the date that an artwork was acquired by the museum in the form `YYYY-MM-DD` (for example, `1964-10-06`) but also may include text with it. If we wanted to filter these values by year, we would not be able to do this in their current string format.
#
# We can convert the values in the `DateAcquired` column to a pandas Datetime data type to use them as a datetime format.
#
# The conversion for the `Date` varaible rather simpler using the pandas method `to_datetime()` on the column.

# %%
development_df["Year"].head(20)
# Out:
# 0     1980
# 1     1981
# 2     1982
# 3     1983
# 4     1984
# 5     1985
# 6     1986
# 7     1987
# 8     1988
# 9     1989
# 10    1990
# 11    1991
# 12    1992
# 13    1993
# 14    1994
# 15    1995
# 16    1996
# 17    1997
# 18    1998
# 19    1999
# Name: Year, dtype: int64

# %%
# sanity check
development_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6426 entries, 0 to 6425
# Data columns (total 25 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Country                                                           6426 non-null   category
#  1   Year                                                              6426 non-null   int64
#  2   Data.Health.Birth Rate                                            6426 non-null   float64
#  3   Data.Health.Death Rate                                            6426 non-null   float64
#  4   Data.Health.Fertility Rate                                        6426 non-null   float64
#  5   Data.Health.Life Expectancy at Birth, Female                      6426 non-null   float64
#  6   Data.Health.Life Expectancy at Birth, Male                        6426 non-null   float64
#  7   Data.Health.Life Expectancy at Birth, Total                       6426 non-null   float64
#  8   Data.Health.Population Growth                                     6426 non-null   float64
#  9   Data.Health.Total Population                                      6426 non-null   float64
#  10  Data.Infrastructure.Mobile Cellular Subscriptions                 6426 non-null   float64
#  11  Data.Infrastructure.Mobile Cellular Subscriptions per 100 People  6426 non-null   float64
#  12  Data.Infrastructure.Telephone Lines                               6426 non-null   float64
#  13  Data.Infrastructure.Telephone Lines per 100 People                6426 non-null   float64
#  14  Data.Rural Development.Agricultural Land                          6426 non-null   float64
#  15  Data.Rural Development.Agricultural Land Percent                  6426 non-null   float64
#  16  Data.Rural Development.Arable Land                                6426 non-null   float64
#  17  Data.Rural Development.Arable Land Percent                        6426 non-null   float64
#  18  Data.Rural Development.Land Area                                  6426 non-null   float64
#  19  Data.Rural Development.Rural Population                           6426 non-null   int64
#  20  Data.Rural Development.Rural Population Growth                    6426 non-null   float64
#  21  Data.Rural Development.Surface Area                               6426 non-null   float64
#  22  Data.Urban Development.Population Density                         6426 non-null   float64
#  23  Data.Urban Development.Urban Population Percent                   6426 non-null   float64
#  24  Data.Urban Development.Urban Population Percent Growth            6426 non-null   float64
# dtypes: category(1), float64(22), int64(2)
# memory usage: 1.2 MB

# %% [markdown]
# The number of rows of not null values in DateYear and Date are not equal.
#
# Check each row for values- always good idea to check the column that gas more null values

# %% [markdown]
# ### 1.2.4. Working with strings

# %% [markdown]
# A lot of the MoMA data consists of strings. There is currently no string data type in pandas, strings are represented by the pandas *object* data type. We can apply string methods to pandas arrays by accessing the `.str` attribute of the array. For example, we can access the string values of the `Artists` column in the full dataset by calling `moma_data[Artists].str`.
#
# If we look at the `Medium` column, we see that the there is a lot of text masking the medium of the painiting. Suppose we wanted to find which the paintings were oil paintings. We could use the string method contains to check for the keyword we are looking for.

# %%
# column Medium can actually be converted to a categorical variable instead of an object
paintings["Medium"].head()

# not so straight forward because each row entry has a different format
#paintings["Medium"] = paintings["Medium"].astype('category')
#paintings["Medium"].head()

# here we need domain expertise - suppose we want to know which paintings are oil paintings
paintings["OilPainting"] = paintings["Medium"].str.contains("oil", case=False)
paintings["OilPainting"].head()

# check the different values and the data type of the values
paintings["OilPainting"].unique()

# convert it into categorical variable
paintings["OilPainting"] = paintings["OilPainting"].astype('category')
# check datatype and values again
paintings["OilPainting"].unique()
# Out:
# [True, False, NaN]
# Categories (2, bool): [False, True]

# %% [markdown]
# ## 1.3. Remove unnecssary values

# %% [markdown]
# ### 1.3.1. Check for duplicate rows, remove them if needed

# %%
# check for duplicate rows using the duplicated().sum() functions - returns number of duplicate rows
# Out:
# 0

# %% [markdown]
# if there was we would drop them with `drop_duplicates()` function called on the entire dataframe .

# %% [markdown]
# ### 1.3.2. Removing unnecessary columns
#
# We can reduce the size of our combined dataset by removing columns that are not important for our analyses. Columns can be "dropped" from a DataFrame using the DataFrame method `drop()`.

# %%
# Print out the column labels for the full dataset of artworks and artist info
paintings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2350 entries, 0 to 2349
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Index               2350 non-null   int64
#  1   Title               2350 non-null   object
#  2   Artist              2349 non-null   object
#  3   ConstituentID       2349 non-null   Int64
#  4   Date                2343 non-null   object
#  5   Medium              2349 non-null   object
#  6   Dimensions          2345 non-null   object
#  7   CreditLine          2343 non-null   object
#  8   AccessionNumber     2350 non-null   object
#  9   Classification      2350 non-null   category
#  10  Department          2350 non-null   category
#  11  DateAcquired        2340 non-null   datetime64[ns]
#  12  Cataloged           2350 non-null   category
#  13  ObjectID            2350 non-null   int64
#  14  URL                 2285 non-null   object
#  15  ThumbnailURL        2099 non-null   object
#  16  Circumference (cm)  0 non-null      category
#  17  Depth (cm)          403 non-null    float64
#  18  Diameter (cm)       12 non-null     float64
#  19  Height (cm)         2320 non-null   float64
#  20  Length (cm)         0 non-null      category
#  21  Weight (kg)         3 non-null      category
#  22  Width (cm)          2317 non-null   float64
#  23  Seat Height (cm)    0 non-null      category
#  24  Duration (sec.)     0 non-null      category
#  25  DateYear            2339 non-null   Int64
#  26  OilPainting         2349 non-null   category
# dtypes: Int64(2), category(9), datetime64[ns](1), float64(4), int64(2), object(9)
# memory usage: 356.9+ KB

# %% [markdown]
# We will not be using any of the external link resources, so we can remove the columns URL, ThumbnailURL.

# %%
# Remove specified columns from the dataset using "drop()"


# Print out the column labels from the new DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2350 entries, 0 to 2349
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Index               2350 non-null   int64
#  1   Title               2350 non-null   object
#  2   Artist              2349 non-null   object
#  3   ConstituentID       2349 non-null   Int64
#  4   Date                2343 non-null   object
#  5   Medium              2349 non-null   object
#  6   Dimensions          2345 non-null   object
#  7   CreditLine          2343 non-null   object
#  8   AccessionNumber     2350 non-null   object
#  9   Classification      2350 non-null   category
#  10  Department          2350 non-null   category
#  11  DateAcquired        2340 non-null   datetime64[ns]
#  12  Cataloged           2350 non-null   category
#  13  ObjectID            2350 non-null   int64
#  14  Circumference (cm)  0 non-null      category
#  15  Depth (cm)          403 non-null    float64
#  16  Diameter (cm)       12 non-null     float64
#  17  Height (cm)         2320 non-null   float64
#  18  Length (cm)         0 non-null      category
#  19  Weight (kg)         3 non-null      category
#  20  Width (cm)          2317 non-null   float64
#  21  Seat Height (cm)    0 non-null      category
#  22  Duration (sec.)     0 non-null      category
#  23  DateYear            2339 non-null   Int64
#  24  OilPainting         2349 non-null   category
# dtypes: Int64(2), category(9), datetime64[ns](1), float64(4), int64(2), object(7)
# memory usage: 320.2+ KB

# %%
# there are also columns that have no entries at all - remove them
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2350 entries, 0 to 2349
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Index            2350 non-null   int64
#  1   Title            2350 non-null   object
#  2   Artist           2349 non-null   object
#  3   ConstituentID    2349 non-null   Int64
#  4   Date             2343 non-null   object
#  5   Medium           2349 non-null   object
#  6   Dimensions       2345 non-null   object
#  7   CreditLine       2343 non-null   object
#  8   AccessionNumber  2350 non-null   object
#  9   Classification   2350 non-null   category
#  10  Department       2350 non-null   category
#  11  DateAcquired     2340 non-null   datetime64[ns]
#  12  Cataloged        2350 non-null   category
#  13  ObjectID         2350 non-null   int64
#  14  Depth (cm)       403 non-null    float64
#  15  Diameter (cm)    12 non-null     float64
#  16  Height (cm)      2320 non-null   float64
#  17  Weight (kg)      3 non-null      category
#  18  Width (cm)       2317 non-null   float64
#  19  DateYear         2339 non-null   Int64
#  20  OilPainting      2349 non-null   category
# dtypes: Int64(2), category(5), datetime64[ns](1), float64(4), int64(2), object(7)
# memory usage: 310.6+ KB

# %% [markdown]
# If more than 30% of the values are null, the column might not be very useful. But if these are rare cases and you are building different model for each case then might make sense to preserve them.

# %% [markdown]
# ## 1.4. Handling missing data
#
# The MoMA paintings dataset contains many missing values. Missing values in a pandas are typically represented as `NaN`. We can handle missing values in several ways,
# - removing all rows or columns containing one or more `NaN`s,
# - removing rows or columns based on the occurrence of `NaN`s within specific rows or columns,
# - filling in `NaN` values with another value usually a domain defualt or known value to represent unknown.
#
# We can do so by using the DataFrame method `dropna()` and specifying a column `subset` over which to look for `NaN`s.

# %%
# check which columns have missing data with info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2350 entries, 0 to 2349
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Index            2350 non-null   int64
#  1   Title            2350 non-null   object
#  2   Artist           2349 non-null   object
#  3   ConstituentID    2349 non-null   Int64
#  4   Date             2343 non-null   object
#  5   Medium           2349 non-null   object
#  6   Dimensions       2345 non-null   object
#  7   CreditLine       2343 non-null   object
#  8   AccessionNumber  2350 non-null   object
#  9   Classification   2350 non-null   category
#  10  Department       2350 non-null   category
#  11  DateAcquired     2340 non-null   datetime64[ns]
#  12  Cataloged        2350 non-null   category
#  13  ObjectID         2350 non-null   int64
#  14  Depth (cm)       403 non-null    float64
#  15  Diameter (cm)    12 non-null     float64
#  16  Height (cm)      2320 non-null   float64
#  17  Weight (kg)      3 non-null      category
#  18  Width (cm)       2317 non-null   float64
#  19  DateYear         2339 non-null   Int64
#  20  OilPainting      2349 non-null   category
# dtypes: Int64(2), category(5), datetime64[ns](1), float64(4), int64(2), object(7)
# memory usage: 310.6+ KB

# %% [markdown]
# ### 1.4.1. Consistency of missing values
#
# The values in the columns can also differ in how they are represented, this includes NaN values.
#
# For example in our dataset the `Date` column was used to create a more consitent `DateYear` column, but there is a difference in the length of each o f these columns.
#
# One needs to understand and eliminate the source of this inconsitency to clean the data.

# %%
# Find rows with NaN in 'col1' and but supposedly has in 'col2'
# Out:
#       DateYear  Date
# 250       <NA>  n.d.
# 920       <NA>  n.d.
# 1221      <NA>  n.d.
# 1717      <NA>  n.d.
# 2011      <NA>   NaN
# 2029      <NA>   NaN
# 2035      <NA>   NaN
# 2042      <NA>   NaN
# 2048      <NA>   NaN
# 2308      <NA>   NaN
# 2320      <NA>   NaN

# %%
# in some cases there can be inconsitency in the how missing values are represented
# we would have to fix that
# for example in the dataset paintings we had both NaN and n.d so we replace all n.d. values with NaN
# call the replace function on specific column and provide arguements on what to replace it by
# for example, paintings['Date'] = paintings['Date'].replace({'n.d.': np.nan})

# %%
paintings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2350 entries, 0 to 2349
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Index            2350 non-null   int64
#  1   Title            2350 non-null   object
#  2   Artist           2349 non-null   object
#  3   ConstituentID    2349 non-null   Int64
#  4   Date             2339 non-null   object
#  5   Medium           2349 non-null   object
#  6   Dimensions       2345 non-null   object
#  7   CreditLine       2343 non-null   object
#  8   AccessionNumber  2350 non-null   object
#  9   Classification   2350 non-null   category
#  10  Department       2350 non-null   category
#  11  DateAcquired     2340 non-null   datetime64[ns]
#  12  Cataloged        2350 non-null   category
#  13  ObjectID         2350 non-null   int64
#  14  Depth (cm)       403 non-null    float64
#  15  Diameter (cm)    12 non-null     float64
#  16  Height (cm)      2320 non-null   float64
#  17  Weight (kg)      3 non-null      category
#  18  Width (cm)       2317 non-null   float64
#  19  DateYear         2339 non-null   Int64
#  20  OilPainting      2349 non-null   category
# dtypes: Int64(2), category(5), datetime64[ns](1), float64(4), int64(2), object(7)
# memory usage: 310.6+ KB

# %% [markdown]
# ### 1.4.2. Removing rows with missing data

# %%
# Identify rows with all NaN values
all_nan_rows = paintings[paintings.isnull().all(axis=1)]
all_nan_rows

# if found remove them
# you can also search for nan values and drop the rows which contain them.
# Out:
# Empty DataFrame
# Columns: [Index, Title, Artist, ConstituentID, Date, Medium, Dimensions, CreditLine, AccessionNumber, Classification, Department, DateAcquired, Cataloged, ObjectID, Depth (cm), Diameter (cm), Height (cm), Weight (kg), Width (cm), DateYear, OilPainting]
# Index: []
#
# [0 rows x 21 columns]

# %%
# Create a new DataFrame containing only paintings that include artist
# information by removing rows that include "NaN" in the column "DateYear"
# using the DataFrame method dropna() on subset of the column(s)


# Print out the resulting DataFrame
# Out:
#    Index                       Title         Artist  ConstituentID  \
# 0  32095          Rope and People, I      Joan Miró           4016
# 1  33167         Fire in the Evening      Paul Klee           3130
# 2  33424  Portrait of an Equilibrist      Paul Klee           3130
# 3  34481                      Guitar  Pablo Picasso           4609
# 4  35396                 Grandmother    Arthur Dove           1602
#
#                         Date  \
# 0  Barcelona, March 27, 1935
# 1                       1929
# 2                       1927
# 3          Paris, early 1919
# 4                       1925
#
#                                               Medium  \
# 0  Oil on cardboard mounted on wood, with coil of...
# 1                                   Oil on cardboard
# 2  Oil and collage on cardboard over wood with pa...
# 3           Oil, charcoal and pinned paper on canvas
# 4  Shingles, needlepoint, page from Concordance, ...
#
#                            Dimensions  \
# 0  41 1/4 x 29 3/8" (104.8 x 74.6 cm)
# 1   13 3/8 x 13 1/4" (33.8 x 33.3 cm)
# 2     24 7/8 x 15 3/4" (63.2 x 40 cm)
# 3         7' 1" x 31" (216 x 78.8 cm)
# 4       20 x 21 1/4" (50.8 x 54.0 cm)
#
#                                 CreditLine AccessionNumber Classification  \
# 0       Gift of the Pierre Matisse Gallery         71.1936       Painting
# 1  Mr. and Mrs. Joachim Jean Aberbach Fund        153.1970       Painting
# 2               Mrs. Simon Guggenheim Fund        195.1966       Painting
# 3               Gift of A. Conger Goodyear        384.1955       Painting
# 4  Gift of Philip L. Goodwin (by exchange)        636.1939       Painting
#
#    ... DateAcquired Cataloged ObjectID  Depth (cm)  Diameter (cm)  \
# 0  ...   1936-10-16         Y    33621         NaN            NaN
# 1  ...   1970-04-08         Y    34854         NaN            NaN
# 2  ...   1966-04-12         Y    35209         NaN            NaN
# 3  ...   1955-12-28         Y    36613         NaN            NaN
# 4  ...   1939-12-08         Y    37674         NaN            NaN
#
#    Height (cm)  Weight (kg) Width (cm)  DateYear  OilPainting
# 0        104.8          NaN       74.6      1935         True
# 1         33.8          NaN       33.3      1929         True
# 2         60.3          NaN       36.8      1927         True
# 3        215.9          NaN       78.7      1919         True
# 4         50.8          NaN       54.0      1925        False
#
# [5 rows x 21 columns]

# %%
# remove all entries where Artist name is null using filtering with notna()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2339 entries, 0 to 2349
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Index            2339 non-null   int64
#  1   Title            2339 non-null   object
#  2   Artist           2339 non-null   object
#  3   ConstituentID    2339 non-null   Int64
#  4   Date             2339 non-null   object
#  5   Medium           2339 non-null   object
#  6   Dimensions       2337 non-null   object
#  7   CreditLine       2332 non-null   object
#  8   AccessionNumber  2339 non-null   object
#  9   Classification   2339 non-null   category
#  10  Department       2339 non-null   category
#  11  DateAcquired     2329 non-null   datetime64[ns]
#  12  Cataloged        2339 non-null   category
#  13  ObjectID         2339 non-null   int64
#  14  Depth (cm)       396 non-null    float64
#  15  Diameter (cm)    11 non-null     float64
#  16  Height (cm)      2310 non-null   float64
#  17  Weight (kg)      3 non-null      category
#  18  Width (cm)       2307 non-null   float64
#  19  DateYear         2339 non-null   Int64
#  20  OilPainting      2339 non-null   category
# dtypes: Int64(2), category(5), datetime64[ns](1), float64(4), int64(2), object(7)
# memory usage: 327.3+ KB

# %% [markdown]
# ### 1.4.3. Replacing missing data
#
# In cases removing the rows is not an option replace the values by default standard which can be either mean in numerical values or any domain dependent value.

# %%
# The dataset contains missing values in height and width column
# replace them with mean value and dropna method
# method 1: df.dropna({col: value}, inplace=True),
# df[column].fillna(newvalue, inplace=True)

# check dataset for sanity
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2350 entries, 0 to 2349
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Index            2350 non-null   int64
#  1   Title            2350 non-null   object
#  2   Artist           2349 non-null   object
#  3   ConstituentID    2349 non-null   Int64
#  4   Date             2339 non-null   object
#  5   Medium           2349 non-null   object
#  6   Dimensions       2345 non-null   object
#  7   CreditLine       2343 non-null   object
#  8   AccessionNumber  2350 non-null   object
#  9   Classification   2350 non-null   category
#  10  Department       2350 non-null   category
#  11  DateAcquired     2340 non-null   datetime64[ns]
#  12  Cataloged        2350 non-null   category
#  13  ObjectID         2350 non-null   int64
#  14  Depth (cm)       403 non-null    float64
#  15  Diameter (cm)    12 non-null     float64
#  16  Height (cm)      2320 non-null   float64
#  17  Weight (kg)      3 non-null      category
#  18  Width (cm)       2350 non-null   float64
#  19  DateYear         2339 non-null   Int64
#  20  OilPainting      2349 non-null   category
# dtypes: Int64(2), category(5), datetime64[ns](1), float64(4), int64(2), object(7)
# memory usage: 310.6+ KB
# <ipython-input-29-1600804c0994>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   paintings["Width (cm)"].fillna(paintings["Width (cm)"].mean(), inplace = True)

# %%
# Any other columns that need similar treatment?

# check for sanity
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2350 entries, 0 to 2349
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Index            2350 non-null   int64
#  1   Title            2350 non-null   object
#  2   Artist           2349 non-null   object
#  3   ConstituentID    2349 non-null   Int64
#  4   Date             2339 non-null   object
#  5   Medium           2349 non-null   object
#  6   Dimensions       2345 non-null   object
#  7   CreditLine       2343 non-null   object
#  8   AccessionNumber  2350 non-null   object
#  9   Classification   2350 non-null   category
#  10  Department       2350 non-null   category
#  11  DateAcquired     2340 non-null   datetime64[ns]
#  12  Cataloged        2350 non-null   category
#  13  ObjectID         2350 non-null   int64
#  14  Depth (cm)       403 non-null    float64
#  15  Diameter (cm)    12 non-null     float64
#  16  Height (cm)      2350 non-null   float64
#  17  Weight (kg)      3 non-null      category
#  18  Width (cm)       2350 non-null   float64
#  19  DateYear         2339 non-null   Int64
#  20  OilPainting      2349 non-null   category
# dtypes: Int64(2), category(5), datetime64[ns](1), float64(4), int64(2), object(7)
# memory usage: 310.6+ KB
# <ipython-input-30-c08c22916450>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   paintings["Height (cm)"].fillna(paintings["Height (cm)"].mean(), inplace = True)

# %% [markdown]
# ## 1.5 Dealing with outliers
#
# Outliers are data points that significantly differ from other observations in a dataset. They are unusual or extreme values that deviate from the typical patterns or central tendency of the data. Outliers can be caused by various factors, including:
#
# - **Measurement errors:** Mistakes in data collection or recording.
# Data entry errors: Typos or incorrect values entered into a database.
#
# - **Experimental errors:** Issues with the experimental setup or procedure.
#
# - **Natural variations:** Genuine extreme values that occur naturally in the population.
#
# Outliers can have a significant impact on data analysis and statistical modeling. Knowing how to deal with outliers is an important data cleaning task.

# %% [markdown]
# ### 1.5.1. Summary Statistics
#
# Summary statistics can be used to identify columns that would need more cleaning, for example if you find that the standard deviation is large compared to the mean - the data may include outliers.
#
# Best way to spot outliers is to plot the data, you can use histograms, box plots and sometimes even scatter plots help in identifying outliers.

# %%
# get summary statistics of the numerical columns
paintings.describe()
# Out:
#                Index  ConstituentID                   DateAcquired  \
# count    2350.000000         2349.0                           2340
# mean    81894.149362    7711.319285  1978-07-03 14:54:46.153846144
# min     32095.000000           11.0            1930-01-12 00:00:00
# 25%     73627.250000         2322.0            1958-10-29 00:00:00
# 50%     74222.500000         4057.0            1978-12-12 00:00:00
# 75%     75957.250000         5640.0            1999-10-12 00:00:00
# max    138106.000000       132956.0            2020-10-26 00:00:00
# std     16957.052200   14243.091181                            NaN
#
#             ObjectID  Depth (cm)  Diameter (cm)  Height (cm)   Width (cm)  \
# count    2350.000000  403.000000      12.000000  2350.000000  2350.000000
# mean    99870.492766    8.147344     138.357934   122.088290   130.123980
# min     33621.000000    0.000000      21.300000     0.000000     0.000000
# 25%     79073.250000    0.000000     116.190025    61.000000    60.055700
# 50%     79852.500000    0.000000     153.850000   105.943231    99.000000
# 75%     82274.000000    5.000000     182.900000   177.675000   165.025000
# max    417640.000000  647.700000     203.200000  1011.000000  4663.449300
# std     50248.368832   38.135901      61.507546    78.906037   150.115422
#
#           DateYear
# count       2339.0
# mean    2224.84395
# min            2.0
# 25%         1937.0
# 50%         1960.0
# 75%         1979.0
# max         9798.0
# std    1151.468916

# %% [markdown]
# ### Plotting data to identify outliers

# %% [markdown]
# ### 1.5.2. The pandas plot method
#
# Plotting data with pandas can be accomplished using the `plot()` method available on both `Series` and `DataFrame` objects. By default, when calling the `plot()` method pandas creates a `line` plot, assuming the data referenced for the plot is numeric. By default, pandas uses the Python visualization library `matplotlib` as the plotting backend for the `plot()` method.
#
# We will explore the results of calling `plot()` with `scatter()` method.

# %% [markdown]
# The previous notebooks had examples of using histograms and box plots for outlier detection, here we explore scatter plots. Use what is convenient. Some statistical processes require historgram or box plot based outlier detection. (e.g. when distribution shape is important)

# %%
# Call the plot() method on the entire paintings DataFrame
paintings.plot.scatter(x= 'Width (cm)', y = 'Height (cm)')
# Out:
# <Axes: xlabel='Width (cm)', ylabel='Height (cm)'>

# %% [markdown]
# You might want to inspect these values and decide if keeping them or removing them makes sense for the analyses you have in mind.

# %%
# remove the rows with the identified outliers with three largest values in the column we get the index
paintings_todrop = paintings["Width (cm)"].nlargest(3).index

# create a dataframe with the two rows dropped
paintings_dropped = paintings.drop(paintings_todrop)

# check the new df
paintings_dropped.plot.scatter(x= 'Width (cm)', y = 'Height (cm)')
# Out:
# <Axes: xlabel='Width (cm)', ylabel='Height (cm)'>

# %%
# do the same for the outlier in height
paintings_todrop = paintings_dropped["Height (cm)"].nlargest(1).index

# create a dataframe with the two rows dropped
paintings_cleaned = paintings_dropped.drop(paintings_todrop)

# check the new df
paintings_cleaned.plot.scatter(x= 'Width (cm)', y = 'Height (cm)')
# Out:
# <Axes: xlabel='Width (cm)', ylabel='Height (cm)'>

# %% [markdown]
# > When do you stop to remove outliers?
# after removing these values your plot would zoom in, but be careful not to over do this. Scatter plots are less reliable ways to remove outliers but sometimes can be intuitive.

# %% [markdown]
# ### 1.5.3. Saving a plot
#
# `matplotlib` provides functionality for saving a figure as an image using the method `savefig()`. We need to get the figure from our plot by calling `get_figure` on the matplotlib `Axes` object and then calling the method `savefig()`.

# %%
# Save the top nationalities plot as a png


# Save a high resolution version of the plot by setting a high dpi


# Save a vectorized version of the plot (svg)

# %% [markdown]
# ### Other plotting libraries
#
# There are many other Python visualization libraries beyond `matplotlib`. Depending on your visualization needs, there are libraries that offer additional features such as advanced plot types, enhanced styling options, the ability to plot large datasets, and interactivity. We will introduce two popular plotting libraries, **Seaborn** and **Altair**, that provide additional functionality while also working well with pandas data structures.
#
# You can find an exhaustive overview of Python visualization tools on the [PyViz website](https://pyviz.org/index.html).

# %% [markdown]
# #### Seaborn
#
# Seaborn is a "Matplotlib-based high-level interface for drawing statistical graphics." Seaborn builds upon the functionality of matplotlib and provides more robust options. You can learn more and find documentation on the [seaborn website](https://seaborn.pydata.org/)

# %%
# Import the Seaborn library as sns (callable in our code as sns)

# %% [markdown]
# We will use the seaborn `scatterplot()` method to generate the same scatter plot we created earlier of the width and height of smaller paintings, but this time will use seaborn's easy functionality fo encoding data into the color of the scatter plot points.
#
# With most seaborn plotting methods we pass in keyword arguments to specify the data source (`data=small_paintings`) and the specific encodings of the data in the plot, in our case the horizontal axis variable (`x='Width (cm)'`), the vertical axis variable (`y='Height (cm)'`), and the variable represented by color (`hue='AspectString'`).

# %%
# Create a seaborn scatter plot, plotting "Width (cm)" on the
# horizontal axis and "Height (cm)" on the vertical axis and using
# "AspectString" to define the color of each point

# %% [markdown]
# ## 1.6. Data Wrangling
#
# > Wrangling is often used to change into a format that is usable, includes merging, subsetting and transformation.

# %% [markdown]
# ### 1.6.1. Replacing values in a column
#
# We can replace values in a column by first accessing that column and using the Series method `replace()` (*remember accessing one column from a DataFrame returns a pandas Series*). The `replace()` method can accept a dictionary of items in which the dictionary keys are the values to be replaced and the dictionary values are the new values to be inserted.
#
# We will demonstrate this method by replacing the values `Y` and `N` in the `Cataloged` column to the more explicit values `Yes` and `No`, respectively. Also, we will edit the DataFrame directly by including the keyword argument `inplace=True`.

# %%
# print the columns and the number of values and datatypes for reference
paintings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2350 entries, 0 to 2349
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Index            2350 non-null   int64
#  1   Title            2350 non-null   object
#  2   Artist           2349 non-null   object
#  3   ConstituentID    2349 non-null   Int64
#  4   Date             2339 non-null   object
#  5   Medium           2349 non-null   object
#  6   Dimensions       2345 non-null   object
#  7   CreditLine       2343 non-null   object
#  8   AccessionNumber  2350 non-null   object
#  9   Classification   2350 non-null   category
#  10  Department       2350 non-null   category
#  11  DateAcquired     2340 non-null   datetime64[ns]
#  12  Cataloged        2350 non-null   category
#  13  ObjectID         2350 non-null   int64
#  14  Depth (cm)       403 non-null    float64
#  15  Diameter (cm)    12 non-null     float64
#  16  Height (cm)      2350 non-null   float64
#  17  Weight (kg)      3 non-null      category
#  18  Width (cm)       2350 non-null   float64
#  19  DateYear         2339 non-null   Int64
#  20  OilPainting      2349 non-null   category
# dtypes: Int64(2), category(5), datetime64[ns](1), float64(4), int64(2), object(7)
# memory usage: 310.6+ KB

# %%
# Print the unique values contained in the "Cataloged" column using the
# DataFrame method unique()
paintings["Cataloged"].unique()
# Out:
# ['Y', 'N']
# Categories (2, object): ['N', 'Y']

# %%
# Replace the values "Y" and "N" in the "Cataloged" column with "Yes" and "No"
paintings["Cataloged"] = paintings["Cataloged"].replace({"Y": "Yes", "N": "No"})

# Print out the unique values of the "Cataloged" column
paintings["Cataloged"].unique()
# Out:
# <ipython-input-40-848903d94ec0>:2: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   paintings["Cataloged"] = paintings["Cataloged"].replace({"Y": "Yes", "N": "No"})
# ['Yes', 'No']
# Categories (2, object): ['No', 'Yes']

# %% [markdown]
# ### 1.6.2. Filtering rows in a DataFrame
#
# > Sometimes you need only part of one dataset, filtering rows becomes important in that case.
#
# We can filter rows of a DataFrame using conditional statements to test if values within one or more columns meet the provided criteria. This is helpful if say we want to remove unnecessary rows of data or observe a specific range of data.
#
# Let's first demonstrate the structure of writing a conditional statement to test the values of a single column by identifying all paintings by Picasso("Artist" == "Pablo Picasso")

# %%
# Filter the final DataFrame to only return rows of artworks by Pablo Picasso
paintings[paintings["Artist"] == "Pablo Picasso"]
# Out:
#       Index                                              Title         Artist  \
# 3     34481                                             Guitar  Pablo Picasso
# 18    73046                               Girl before a Mirror  Pablo Picasso
# 103   73131                                            Pierrot  Pablo Picasso
# 107   73135                           Night Fishing at Antibes  Pablo Picasso
# 209   73237                                  Woman by a Window  Pablo Picasso
# 216   73245                                  Violin and Grapes  Pablo Picasso
# 249   73281                                    Three Musicians  Pablo Picasso
# 304   73336                                          Harlequin  Pablo Picasso
# 323   73355                       The Reservoir, Horta de Ebro  Pablo Picasso
# 326   73358                                      Seated Bather  Pablo Picasso
# 350   73382                                   Green Still Life  Pablo Picasso
# 354   73386                                  The Charnel House  Pablo Picasso
# 388   73421                                           The Rape  Pablo Picasso
# 434   73467                           Studio with Plaster Head  Pablo Picasso
# 525   73560                     Still Life with Liqueur Bottle  Pablo Picasso
# 575   73615                                         "Ma Jolie"  Pablo Picasso
# 576   73616                                        Card Player  Pablo Picasso
# 652   73692                                         The Studio  Pablo Picasso
# 776   73817                                         Fruit Dish  Pablo Picasso
# 804   73846                                       Bearded Faun  Pablo Picasso
# 808   73850                                     Head of a Faun  Pablo Picasso
# 818   73860  Head of a Sleeping Woman (Study for Nude with ...  Pablo Picasso
# 822   73864                    Still Life with Fruit and Glass  Pablo Picasso
# 908   73950                                   Bather and Cabin  Pablo Picasso
# 914   73956                                            At Work  Pablo Picasso
# 917   73959                              Maya in a Sailor Suit  Pablo Picasso
# 955   73997                Study for Les Demoiselles D'Avignon  Pablo Picasso
# 1027  74070                                Woman with a Guitar  Pablo Picasso
# 1043  74086                                        The Kitchen  Pablo Picasso
# 1087  74132                                    Vase of Flowers  Pablo Picasso
# 1110  74158                          Three Women at the Spring  Pablo Picasso
# 1114  74162                          Les Demoiselles d'Avignon  Pablo Picasso
# 1207  74256                                       Seated Woman  Pablo Picasso
# 1225  74275                               Woman in an Armchair  Pablo Picasso
# 1264  74314                                Boy Leading a Horse  Pablo Picasso
# 1266  74316                                             Repose  Pablo Picasso
# 1286  74336                                 Self Portrait (Yo)  Pablo Picasso
# 1345  74396                                          Two Nudes  Pablo Picasso
# 1377  74428                          Glass, Guitar, and Bottle  Pablo Picasso
# 1379  74430                                  Painter and Model  Pablo Picasso
# 1442  74493                             Bather with Beach Ball  Pablo Picasso
# 1454  74505                              The Architect's Table  Pablo Picasso
# 1493  74546                                             Bather  Pablo Picasso
# 1494  74547                            Woman Dressing Her Hair  Pablo Picasso
# 1509  74562                                       Woman's Head  Pablo Picasso
# 1510  74563                            Woman Plaiting Her Hair  Pablo Picasso
# 1511  74564                                   Woman with Pears  Pablo Picasso
# 1512  74565                               Woman in an Armchair  Pablo Picasso
# 1532  74585               Girl with a Mandolin (Fanny Tellier)  Pablo Picasso
# 1533  74586                       Interior with a Girl Drawing  Pablo Picasso
# 1534  74587                                  Still Life: "Job"  Pablo Picasso
# 1535  74588                                Student with a Pipe  Pablo Picasso
# 1689  74743                              Nude Seated on a Rock  Pablo Picasso
# 1690  74744                                           The Sigh  Pablo Picasso
# 1725  74780                                          Landscape  Pablo Picasso
#
#       ConstituentID                                               Date  \
# 3              4609                                  Paris, early 1919
# 18             4609                              Paris, March 14, 1932
# 103            4609                                        Paris, 1918
# 107            4609                               Antibes, August 1939
# 209            4609                                  Cannes, June 1956
# 216            4609              Céret and Sorgues, spring-summer 1912
# 249            4609                         Fontainebleau, summer 1921
# 304            4609                                   Paris, late 1915
# 323            4609                    Horta de Sant Joan, summer 1909
# 326            4609                                  Paris, early 1930
# 350            4609                               Avignon, summer 1914
# 354            4609                                     Paris, 1944-45
# 388            4609                                Juan-les-Pins, 1920
# 434            4609                         Juan-les-Pins, summer 1925
# 525            4609                     Horta de San Joan, August 1909
# 575            4609                              Paris, winter 1911-12
# 576            4609                              Paris, winter 1913-14
# 652            4609                              Paris, winter 1927-28
# 776            4609                              Paris, winter 1908-09
# 804            4609                                  February 15, 1956
# 808            4609                      January 24 - February 6, 1956
# 818            4609                                 Paris, summer 1907
# 822            4609                                   Paris, fall 1908
# 908            4609                                Dinard, August 1928
# 914            4609                                    August 15, 1971
# 917            4609                                               1938
# 955            4609                                  Paris, early 1907
# 1027           4609                                  Paris, March 1914
# 1043           4609                               Paris, November 1948
# 1087           4609                                 Paris, spring 1908
# 1110           4609                         Fontainebleau, summer 1921
# 1114           4609                              Paris, June-July 1907
# 1207           4609                                        Paris, 1927
# 1225           4609                                   Mougins, 1961-62
# 1264           4609                                     Paris, 1905-06
# 1266           4609                                 Paris, spring 1908
# 1286           4609                                               1901
# 1345           4609                                   Paris, late 1906
# 1377           4609                                  Paris, early 1913
# 1379           4609                                        Paris, 1928
# 1442           4609                        Boisgeloup, August 30, 1932
# 1454           4609                                  Paris, early 1912
# 1493           4609                                     winter 1908-09
# 1494           4609                                   Royan, June 1940
# 1509           4609                                         early 1908
# 1510           4609                    Paris, late summer or fall 1906
# 1511           4609                     Horta de San Joan, summer 1909
# 1512           4609                                          July 1941
# 1532           4609                            Paris, late spring 1910
# 1533           4609                               Paris, February 1935
# 1534           4609                                         Paris 1916
# 1535           4609                      Paris, autumn 1913–early 1914
# 1689           4609                         Fontainebleau, summer 1921
# 1690           4609                                        Paris, 1923
# 1725           4609  La Rue des Bois or Paris, August or September ...
#
#                                                  Medium  \
# 3              Oil, charcoal and pinned paper on canvas
# 18                                        Oil on canvas
# 103                                       Oil on canvas
# 107                                       Oil on canvas
# 209                                       Oil on canvas
# 216                                       Oil on canvas
# 249                                       Oil on canvas
# 304                                       Oil on canvas
# 323                                       Oil on canvas
# 326                                       Oil on canvas
# 350                                       Oil on canvas
# 354                          Oil and charcoal on canvas
# 388                                     Tempera on wood
# 434                                       Oil on canvas
# 525                                       Oil on canvas
# 575                                       Oil on canvas
# 576                                       Oil on canvas
# 652                                       Oil on canvas
# 776                                       Oil on canvas
# 804                                      Enamel on tile
# 808                                      Enamel on tile
# 818                                       Oil on canvas
# 822                                     Tempera on wood
# 908                                       Oil on canvas
# 914                                       Oil on canvas
# 917                                       Oil on canvas
# 955                                       Oil on canvas
# 1027                  Oil, sand, and charcoal on canvas
# 1043                                      Oil on canvas
# 1087                                      Oil on canvas
# 1110                                      Oil on canvas
# 1114                                      Oil on canvas
# 1207                                        Oil on wood
# 1225                                      Oil on canvas
# 1264                                      Oil on canvas
# 1266                                      Oil on canvas
# 1286                   Oil on cardboard mounted on wood
# 1345                                      Oil on canvas
# 1377  Oil, cut-and-pasted newspaper, charcoal, and p...
# 1379                                      Oil on canvas
# 1442                                      Oil on canvas
# 1454                     Oil on canvas mounted on panel
# 1493                                      Oil on canvas
# 1494                                      Oil on canvas
# 1509                                      Oil on canvas
# 1510                                      Oil on canvas
# 1511                                      Oil on canvas
# 1512                                      Oil on canvas
# 1532                                      Oil on canvas
# 1533                                      Oil on canvas
# 1534                             Oil and sand on canvas
# 1535  Oil, gouache, cut-and-pasted paper, gesso, san...
# 1689                                        Oil on wood
# 1690                         Oil and charcoal on canvas
# 1725                                      Oil on canvas
#
#                                     Dimensions  \
# 3                  7' 1" x 31" (216 x 78.8 cm)
# 18             64 x 51 1/4" (162.3 x 130.2 cm)
# 103            36 1/2 x 28 3/4" (92.7 x 73 cm)
# 107          6' 9" x 11' 4" (205.8 x 345.4 cm)
# 209            63 3/4 x 51 1/4" (162 x 130 cm)
# 216                    24 x 20" (61 x 50.8 cm)
# 249       6' 7" x 7' 3 3/4" (200.7 x 222.9 cm)
# 304       6' 1/4" x 41 3/8" (183.5 x 105.1 cm)
# 323          24 1/8 x 20 1/8" (61.5 x 51.1 cm)
# 326            64 1/4 x 51" (163.2 x 129.5 cm)
# 350          23 1/2 x 31 1/4" (59.7 x 79.4 cm)
# 354   6' 6 5/8" x 8' 2 1/2" (199.8 x 250.1 cm)
# 388           9 3/8 x 12 7/8" (23.8 x 32.6 cm)
# 434         38 5/8 x 51 5/8" (97.9 x 131.1 cm)
# 525          32 1/8 x 25 3/4" (81.6 x 65.4 cm)
# 575           39 3/8 x 25 3/4" (100 x 64.5 cm)
# 576           42 1/2 x 35 1/4" (108 x 89.5 cm)
# 652             59" x 7' 7" (149.9 x 231.2 cm)
# 776                29 1/4 x 24" (74.3 x 61 cm)
# 804                    8 x 8" (20.3 x 20.3 cm)
# 808                    8 x 8" (20.3 x 20.3 cm)
# 818          24 1/4 x 18 3/4" (61.4 x 47.6 cm)
# 822             10 5/8 x 8 3/8" (27 x 21.1 cm)
# 908            8 1/2 x 6 1/4" (21.5 x 15.8 cm)
# 914        63 3/4 x 51 1/4" (161.9 x 130.2 cm)
# 917             47 7/8 x 34" (121.6 x 86.3 cm)
# 955    7 1/2 x 8" (18.5 x 20.3 cm) (irregular)
# 1027        45 1/2 x 18 5/8" (115.5 x 47.5 cm)
# 1043          69" x 8' 2 1/2" (175.3 x 250 cm)
# 1087           36 1/4 x 28 3/4" (92.1 x 73 cm)
# 1110      6' 8 1/4" x 68 1/2" (203.9 x 174 cm)
# 1114             8' x 7' 8" (243.9 x 233.7 cm)
# 1207        51 1/8 x 38 1/4" (129.9 x 96.8 cm)
# 1225       63 7/8 x 51 1/8" (162.3 x 129.8 cm)
# 1264    7' 2 7/8" x 51 5/8" (220.6 x 131.2 cm)
# 1266             32 x 25 3/4" (81.2 x 65.4 cm)
# 1286         20 1/4 x 12 1/2" (51.4 x 31.8 cm)
# 1345          59 5/8 x 36 5/8" (151.3 x 93 cm)
# 1377         25 3/4 x 21 1/8" (65.4 x 53.6 cm)
# 1379         51 1/8 x 64 1/4" (129.8 x 163 cm)
# 1442       57 7/8 x 45 1/8" (146.2 x 114.6 cm)
# 1454         28 5/8 x 23 1/2" (72.6 x 59.7 cm)
# 1493        51 1/8 x 38 1/8" (129.8 x 96.8 cm)
# 1494        51 1/4 x 38 1/4" (130.1 x 97.1 cm)
# 1509             29 x 23 7/8" (73.6 x 60.6 cm)
# 1510              50 x 35 3/4" (127 x 90.8 cm)
# 1511         36 1/4 x 27 7/8" (92.1 x 70.8 cm)
# 1512             36 3/8 x 29" (92.4 x 73.6 cm)
# 1532            39 1/2 x 29" (100.3 x 73.6 cm)
# 1533         51 1/4 x 6' 4 5/8" (130 x 195 cm)
# 1534             17 x 13 3/4" (43.2 x 34.9 cm)
# 1535           28 3/4 x 23 1/8" (73 x 58.7 cm)
# 1689           6 1/4 x 4 3/8" (15.8 x 11.1 cm)
# 1690         23 3/4 x 19 3/4" (60.3 x 50.2 cm)
# 1725            39 5/8 x 32" (100.8 x 81.3 cm)
#
#                                              CreditLine AccessionNumber  \
# 3                            Gift of A. Conger Goodyear        384.1955
# 18                        Gift of Mrs. Simon Guggenheim          2.1938
# 103                             Sam A. Lewisohn Bequest         12.1952
# 107                          Mrs. Simon Guggenheim Fund         13.1952
# 209                          Mrs. Simon Guggenheim Fund         30.1957
# 216                          Mrs. David M. Levy Bequest         32.1960
# 249                          Mrs. Simon Guggenheim Fund         55.1949
# 304   Acquired through the Lillie P. Bliss Bequest (...         76.1950
# 323              Gift of Mr. and Mrs. David Rockefeller         81.1991
# 326                          Mrs. Simon Guggenheim Fund         82.1950
# 350                          Lillie P. Bliss Collection         92.1934
# 354   Mrs. Sam A. Lewisohn Bequest (by exchange), an...         93.1971
# 388                    The Philip L. Goodwin Collection        106.1958
# 434                                            Purchase        116.1964
# 525                          Mrs. Simon Guggenheim Fund        147.1951
# 575   Acquired through the Lillie P. Bliss Bequest (...        176.1945
# 576   Acquired through the Lillie P. Bliss Bequest (...        177.1945
# 652                     Gift of Walter P. Chrysler, Jr.        213.1935
# 776   Acquired through the Lillie P. Bliss Bequest (...        263.1944
# 804                                 Philip Johnson Fund        274.1956
# 808                                 Philip Johnson Fund        275.1956
# 818                          Estate of John Hay Whitney        278.1983
# 822                          Estate of John Hay Whitney        279.1983
# 908                            Hillman Periodicals Fund        342.1955
# 914   Gift of Jacqueline Picasso in honor of the Mus...        344.1985
# 917   Gift of Jacqueline Picasso in honor of the Mus...        346.1985
# 955   Acquired through the Lillie P. Bliss Bequest (...        372.1991
# 1027             Gift of Mr. and Mrs. David Rockefeller        415.1975
# 1043  Acquired through the Nelson A. Rockefeller Beq...        422.1980
# 1087                Gift of Mr. and Mrs. Ralph F. Colin        311.1962
# 1110                 Gift of Mr. and Mrs. Allan D. Emil        332.1952
# 1114  Acquired through the Lillie P. Bliss Bequest (...        333.1939
# 1207                          Gift of James Thrall Soby        516.1961
# 1225             Gift of Mr. and Mrs. David Rockefeller        529.1964
# 1264                    The William S. Paley Collection        575.1964
# 1266  Acquired by exchange through the Katherine S. ...        575.1970
# 1286                      Mrs. John Hay Whitney Bequest        587.1998
# 1345  Gift of G. David Thompson in honor of Alfred H...        621.1959
# 1377            The Sidney and Harriet Janis Collection        641.1967
# 1379            The Sidney and Harriet Janis Collection        644.1967
# 1442  Partial gift of an anonymous donor and promise...        689.1980
# 1454                    The William S. Paley Collection        697.1971
# 1493                     Louise Reinhardt Smith Bequest        786.1995
# 1494                     Louise Reinhardt Smith Bequest        788.1995
# 1509                     Florene May Schoenborn Bequest        825.1996
# 1510                     Florene May Schoenborn Bequest        826.1996
# 1511                     Florene May Schoenborn Bequest        827.1996
# 1512                     Florene May Schoenborn Bequest        828.1996
# 1532                      Nelson A. Rockefeller Bequest        966.1979
# 1533                      Nelson A. Rockefeller Bequest        969.1979
# 1534                      Nelson A. Rockefeller Bequest        971.1979
# 1535                      Nelson A. Rockefeller Bequest        973.1979
# 1689                          James Thrall Soby Bequest       1242.1979
# 1690                          James Thrall Soby Bequest       1243.1979
# 1725             Gift of Mr. and Mrs. David Rockefeller       1413.1974
#
#      Classification  ... DateAcquired Cataloged ObjectID  Depth (cm)  \
# 3          Painting  ...   1955-12-28       Yes    36613         NaN
# 18         Painting  ...   1937-12-17       Yes    78311         NaN
# 103        Painting  ...   1952-01-22       Yes    78427         NaN
# 107        Painting  ...   1952-01-22       Yes    78433         NaN
# 209        Painting  ...   1956-05-15       Yes    78569         NaN
# 216        Painting  ...   1960-04-06       Yes    78578         NaN
# 249        Painting  ...   1949-03-24       Yes    78630         NaN
# 304        Painting  ...   1950-01-27       Yes    78696         NaN
# 323        Painting  ...   1991-04-08       Yes    78718         NaN
# 326        Painting  ...   1950-01-27       Yes    78721         NaN
# 350        Painting  ...   1934-09-23       Yes    78748         NaN
# 354        Painting  ...   1971-03-09       Yes    78752         NaN
# 388        Painting  ...   1958-10-29       Yes    78802         NaN
# 434        Painting  ...   1964-02-11       Yes    78860         NaN
# 525        Painting  ...   1951-05-24       Yes    78986         NaN
# 575        Painting  ...   1945-12-17       Yes    79051         NaN
# 576        Painting  ...   1945-12-17       Yes    79052         NaN
# 652        Painting  ...   1935-11-12       Yes    79164         NaN
# 776        Painting  ...   1944-11-08       Yes    79322         NaN
# 804        Painting  ...   1956-10-09       Yes    79357         NaN
# 808        Painting  ...   1956-10-09       Yes    79362         NaN
# 818        Painting  ...   1983-02-14       Yes    79376         NaN
# 822        Painting  ...   1983-02-14       Yes    79380         NaN
# 908        Painting  ...   1955-11-23       Yes    79496         NaN
# 914        Painting  ...   1985-10-25       Yes    79503         NaN
# 917        Painting  ...   1985-10-25       Yes    79507         NaN
# 955        Painting  ...   1991-12-09       Yes    79551         NaN
# 1027       Painting  ...   1975-12-29       Yes    79646         NaN
# 1043       Painting  ...   1980-04-09       Yes    79668         NaN
# 1087       Painting  ...   1962-12-11       Yes    79731         NaN
# 1110       Painting  ...   1952-12-08       Yes    79762         NaN
# 1114       Painting  ...   1939-04-24       Yes    79766         NaN
# 1207       Painting  ...   1962-12-12       Yes    79895         NaN
# 1225       Painting  ...   1964-06-15       Yes    79928         NaN
# 1264       Painting  ...   1964-10-06       Yes    79994         NaN
# 1266       Painting  ...   1970-12-08       Yes    79996         NaN
# 1286       Painting  ...   1998-09-22       Yes    80026         NaN
# 1345       Painting  ...   1959-04-22       Yes    80111         NaN
# 1377       Painting  ...   1967-10-18       Yes    80162         NaN
# 1379       Painting  ...   1967-10-18       Yes    80166         NaN
# 1442       Painting  ...   1980-12-09       Yes    80262         NaN
# 1454       Painting  ...   1971-12-21       Yes    80280         NaN
# 1493       Painting  ...   1995-12-12       Yes    80357         NaN
# 1494       Painting  ...   1995-12-12       Yes    80360         NaN
# 1509       Painting  ...   1996-12-09       Yes    80391         NaN
# 1510       Painting  ...   1996-12-09       Yes    80393         NaN
# 1511       Painting  ...   1996-12-09       Yes    80394         NaN
# 1512       Painting  ...   1996-12-09       Yes    80396         NaN
# 1532       Painting  ...   1979-10-09       Yes    80430         NaN
# 1533       Painting  ...   1979-10-09       Yes    80432         NaN
# 1534       Painting  ...   1979-10-09       Yes    80434         NaN
# 1535       Painting  ...   1979-10-09       Yes    80436         NaN
# 1689       Painting  ...   1979-12-11       Yes    80609         NaN
# 1690       Painting  ...   1979-12-11       Yes    80611         NaN
# 1725       Painting  ...   1975-02-11       Yes    80660         NaN
#
#       Diameter (cm)  Height (cm)  Weight (kg) Width (cm)  DateYear  \
# 3               NaN     215.9000          NaN    78.7000      1919
# 18              NaN     162.3000          NaN   130.2000      1932
# 103             NaN      92.7000          NaN    73.0000      1918
# 107             NaN     205.8000          NaN   345.4000      1939
# 209             NaN     162.0000          NaN   130.0000      1956
# 216             NaN      60.9601          NaN    50.8001      1912
# 249             NaN     200.7000          NaN   222.9000      1921
# 304             NaN     183.5000          NaN   105.1000      1915
# 323             NaN      61.5000          NaN    51.1000      1909
# 326             NaN     163.2000          NaN   129.5000      1930
# 350             NaN      59.7000          NaN    79.4000      1914
# 354             NaN     199.8000          NaN   250.1000      4445
# 388             NaN      23.8000          NaN    32.6000      1920
# 434             NaN      97.9000          NaN   131.1000      1925
# 525             NaN      81.6000          NaN    65.4000      1909
# 575             NaN     100.0000          NaN    64.5000      1112
# 576             NaN     108.0000          NaN    89.5000      1314
# 652             NaN     149.9000          NaN   231.2000      2728
# 776             NaN      74.3000          NaN    61.0000       809
# 804             NaN      20.3000          NaN    20.3000      1956
# 808             NaN      20.3000          NaN    20.3000      1956
# 818             NaN      61.4000          NaN    47.6000      1907
# 822             NaN      27.0000          NaN    21.1000      1908
# 908             NaN      21.6000          NaN    15.9000      1928
# 914             NaN     161.9000          NaN   130.2000      1971
# 917             NaN     121.6000          NaN    86.3000      1938
# 955             NaN      19.0000          NaN    20.3000      1907
# 1027            NaN     115.5000          NaN    47.5000      1914
# 1043            NaN     175.3000          NaN   250.0000      1948
# 1087            NaN      92.1000          NaN    73.0000      1908
# 1110            NaN     203.9000          NaN   174.0000      1921
# 1114            NaN     243.9000          NaN   233.7000      1907
# 1207            NaN     129.9000          NaN    96.8000      1927
# 1225            NaN     162.3000          NaN   129.8000      6162
# 1264            NaN     220.3000          NaN   131.1278       506
# 1266            NaN      81.2000          NaN    65.4000      1908
# 1286            NaN      51.4000          NaN    31.8000      1901
# 1345            NaN     151.3000          NaN    93.0000      1906
# 1377            NaN      65.4000          NaN    53.6000      1913
# 1379            NaN     129.8000          NaN   163.0000      1928
# 1442            NaN     146.2000          NaN   114.6000      1932
# 1454            NaN      72.6000          NaN    59.7000      1912
# 1493            NaN     129.9000          NaN    96.8000       809
# 1494            NaN     130.2000          NaN    97.2000      1940
# 1509            NaN      73.6000          NaN    60.6000      1908
# 1510            NaN     127.0000          NaN    90.8000      1906
# 1511            NaN      92.1000          NaN    70.8000      1909
# 1512            NaN      92.4000          NaN    73.6000      1941
# 1532            NaN     100.3000          NaN    73.6000      1910
# 1533            NaN     130.0000          NaN   195.0000      1935
# 1534            NaN      43.2000          NaN    34.9000      1916
# 1535            NaN      73.0000          NaN    58.7000      1914
# 1689            NaN      15.8000          NaN    11.1000      1921
# 1690            NaN      60.3000          NaN    50.2000      1923
# 1725            NaN     100.8000          NaN    81.3000      1908
#
#       OilPainting
# 3            True
# 18           True
# 103          True
# 107          True
# 209          True
# 216          True
# 249          True
# 304          True
# 323          True
# 326          True
# 350          True
# 354          True
# 388         False
# 434          True
# 525          True
# 575          True
# 576          True
# 652          True
# 776          True
# 804         False
# 808         False
# 818          True
# 822         False
# 908          True
# 914          True
# 917          True
# 955          True
# 1027         True
# 1043         True
# 1087         True
# 1110         True
# 1114         True
# 1207         True
# 1225         True
# 1264         True
# 1266         True
# 1286         True
# 1345         True
# 1377         True
# 1379         True
# 1442         True
# 1454         True
# 1493         True
# 1494         True
# 1509         True
# 1510         True
# 1511         True
# 1512         True
# 1532         True
# 1533         True
# 1534         True
# 1535         True
# 1689         True
# 1690         True
# 1725         True
#
# [55 rows x 21 columns]

# %% [markdown]
# Filtering on multiple conditions has a slightly different syntax than a standard Python conditional statement with logical operators (that is, conditional statements using `and`, `or`, or `not`). When filtering a DataFrame using multiple conditional statements use the operators `|` in place of `or`, `&` in place of `and`, and `~` in place of `not`. Additionally, each statement must be surrounded by parentheses to maintain correct order of operation.
#
# Let's filter the full MoMA artworks DataFrame to return only artworks by by `Pablo Piccaso` (`Artist == Pablo Piccaso`) that were acquired by MoMA before 1950 (`DateYear >= 1950`).

# %%
# Filter the final DataFrame to only return rows of artworks by Pablo Picasso
# acquired before 1950
paintings[(paintings["Artist"] == "Pablo Picasso") & (paintings["DateAcquired"] <= pd.to_datetime(str(1950)))]
# Out:
#       Index                      Title         Artist  ConstituentID  \
# 18    73046       Girl before a Mirror  Pablo Picasso           4609
# 249   73281            Three Musicians  Pablo Picasso           4609
# 350   73382           Green Still Life  Pablo Picasso           4609
# 575   73615                 "Ma Jolie"  Pablo Picasso           4609
# 576   73616                Card Player  Pablo Picasso           4609
# 652   73692                 The Studio  Pablo Picasso           4609
# 776   73817                 Fruit Dish  Pablo Picasso           4609
# 1114  74162  Les Demoiselles d'Avignon  Pablo Picasso           4609
#
#                             Date         Medium  \
# 18         Paris, March 14, 1932  Oil on canvas
# 249   Fontainebleau, summer 1921  Oil on canvas
# 350         Avignon, summer 1914  Oil on canvas
# 575        Paris, winter 1911-12  Oil on canvas
# 576        Paris, winter 1913-14  Oil on canvas
# 652        Paris, winter 1927-28  Oil on canvas
# 776        Paris, winter 1908-09  Oil on canvas
# 1114       Paris, June-July 1907  Oil on canvas
#
#                                 Dimensions  \
# 18         64 x 51 1/4" (162.3 x 130.2 cm)
# 249   6' 7" x 7' 3 3/4" (200.7 x 222.9 cm)
# 350      23 1/2 x 31 1/4" (59.7 x 79.4 cm)
# 575       39 3/8 x 25 3/4" (100 x 64.5 cm)
# 576       42 1/2 x 35 1/4" (108 x 89.5 cm)
# 652         59" x 7' 7" (149.9 x 231.2 cm)
# 776            29 1/4 x 24" (74.3 x 61 cm)
# 1114         8' x 7' 8" (243.9 x 233.7 cm)
#
#                                              CreditLine AccessionNumber  \
# 18                        Gift of Mrs. Simon Guggenheim          2.1938
# 249                          Mrs. Simon Guggenheim Fund         55.1949
# 350                          Lillie P. Bliss Collection         92.1934
# 575   Acquired through the Lillie P. Bliss Bequest (...        176.1945
# 576   Acquired through the Lillie P. Bliss Bequest (...        177.1945
# 652                     Gift of Walter P. Chrysler, Jr.        213.1935
# 776   Acquired through the Lillie P. Bliss Bequest (...        263.1944
# 1114  Acquired through the Lillie P. Bliss Bequest (...        333.1939
#
#      Classification  ... DateAcquired Cataloged ObjectID  Depth (cm)  \
# 18         Painting  ...   1937-12-17       Yes    78311         NaN
# 249        Painting  ...   1949-03-24       Yes    78630         NaN
# 350        Painting  ...   1934-09-23       Yes    78748         NaN
# 575        Painting  ...   1945-12-17       Yes    79051         NaN
# 576        Painting  ...   1945-12-17       Yes    79052         NaN
# 652        Painting  ...   1935-11-12       Yes    79164         NaN
# 776        Painting  ...   1944-11-08       Yes    79322         NaN
# 1114       Painting  ...   1939-04-24       Yes    79766         NaN
#
#       Diameter (cm)  Height (cm)  Weight (kg) Width (cm)  DateYear  \
# 18              NaN        162.3          NaN      130.2      1932
# 249             NaN        200.7          NaN      222.9      1921
# 350             NaN         59.7          NaN       79.4      1914
# 575             NaN        100.0          NaN       64.5      1112
# 576             NaN        108.0          NaN       89.5      1314
# 652             NaN        149.9          NaN      231.2      2728
# 776             NaN         74.3          NaN       61.0       809
# 1114            NaN        243.9          NaN      233.7      1907
#
#       OilPainting
# 18           True
# 249          True
# 350          True
# 575          True
# 576          True
# 652          True
# 776          True
# 1114         True
#
# [8 rows x 21 columns]

# %% [markdown]
# ### 1.6.3. Creating a new column using an expression
#
# We can create new columns of data on an existing DataFrame and assign values calculated from existing columns of data. This is done by first calling the index of the new column (for example, `df['NEW_COLUMN_NAME']`) and assigning the new column the results of some expression that can include existing columns of data from the DataFrame.
#
# We will create a new column named `Area (cm^2)` that contains the centimeter squared area of a painting based on the values provided in the columns `Width (cm)` and `Height (cm)`.

# %%
# Create a new DataFrame column consisting with column
paintings["Area (cm^2)"] = paintings["Height (cm)"] * paintings["Width (cm)"]

# Print out the full DataFrame
paintings.info()

# Create a scatter plot of the new DataFrame, plotting "Width (cm)" on the
# horizontal axis and "Height (cm)" on the vertical axis
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2350 entries, 0 to 2349
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Index            2350 non-null   int64
#  1   Title            2350 non-null   object
#  2   Artist           2349 non-null   object
#  3   ConstituentID    2349 non-null   Int64
#  4   Date             2339 non-null   object
#  5   Medium           2349 non-null   object
#  6   Dimensions       2345 non-null   object
#  7   CreditLine       2343 non-null   object
#  8   AccessionNumber  2350 non-null   object
#  9   Classification   2350 non-null   category
#  10  Department       2350 non-null   category
#  11  DateAcquired     2340 non-null   datetime64[ns]
#  12  Cataloged        2350 non-null   category
#  13  ObjectID         2350 non-null   int64
#  14  Depth (cm)       403 non-null    float64
#  15  Diameter (cm)    12 non-null     float64
#  16  Height (cm)      2350 non-null   float64
#  17  Weight (kg)      3 non-null      category
#  18  Width (cm)       2350 non-null   float64
#  19  DateYear         2339 non-null   Int64
#  20  OilPainting      2349 non-null   category
#  21  Area (cm^2)      2350 non-null   float64
# dtypes: Int64(2), category(5), datetime64[ns](1), float64(5), int64(2), object(7)
# memory usage: 329.0+ KB

# %% [markdown]
# ### 1.6.4. Creating a new column using apply
#
# > Sometimes you need new columns, for eample, in many of your datasets you selected one dataset is from 2001 and another from 2002 so having a column in each before merging them saing year with these values will help you know where the value came from.
#
# Sometimes we need to create new data using more complex methods than a simple expression. We will create a new column named `OilPainting` to identify all painting that contain the word "oil" in their medium description (contained in the column `medium`). This cannot be reliably accomplished without doing some advanced manipulation of the medium description.
#
# We will use the Series method `apply()` to call the function `is_oil_based_painting`, which contains the necessary code to produce the desired results, on the column `Medium`.

# %%
# Return teh duration the painting has been with MoMA
def duration(DateAcquired):
    if DateAcquired is not np.nan:
      return (pd.to_datetime('today') - pd.to_datetime(DateAcquired)).days
    return None
    """
    # Test if value is a string (can't apply string methods on NaNs)
    if type(dateyear) == str:
        # Create a list of lowercase words, commas removed, from description
        description = medium.lower().replace(',', '').split(' ')
        # Test if "oil" is in list
        if 'oil' in description:
            return 'Yes'
        return 'No'
      """

# Use the Series method apply to call the "duration" function on
# the column "DateAcquired"
paintings["Duration (days)"] = paintings["DateAcquired"].apply(duration)

# Print out the resulting DataFrame
paintings.head()
# Out:
#    Index                       Title         Artist  ConstituentID  \
# 0  32095          Rope and People, I      Joan Miró           4016
# 1  33167         Fire in the Evening      Paul Klee           3130
# 2  33424  Portrait of an Equilibrist      Paul Klee           3130
# 3  34481                      Guitar  Pablo Picasso           4609
# 4  35396                 Grandmother    Arthur Dove           1602
#
#                         Date  \
# 0  Barcelona, March 27, 1935
# 1                       1929
# 2                       1927
# 3          Paris, early 1919
# 4                       1925
#
#                                               Medium  \
# 0  Oil on cardboard mounted on wood, with coil of...
# 1                                   Oil on cardboard
# 2  Oil and collage on cardboard over wood with pa...
# 3           Oil, charcoal and pinned paper on canvas
# 4  Shingles, needlepoint, page from Concordance, ...
#
#                            Dimensions  \
# 0  41 1/4 x 29 3/8" (104.8 x 74.6 cm)
# 1   13 3/8 x 13 1/4" (33.8 x 33.3 cm)
# 2     24 7/8 x 15 3/4" (63.2 x 40 cm)
# 3         7' 1" x 31" (216 x 78.8 cm)
# 4       20 x 21 1/4" (50.8 x 54.0 cm)
#
#                                 CreditLine AccessionNumber Classification  \
# 0       Gift of the Pierre Matisse Gallery         71.1936       Painting
# 1  Mr. and Mrs. Joachim Jean Aberbach Fund        153.1970       Painting
# 2               Mrs. Simon Guggenheim Fund        195.1966       Painting
# 3               Gift of A. Conger Goodyear        384.1955       Painting
# 4  Gift of Philip L. Goodwin (by exchange)        636.1939       Painting
#
#    ... ObjectID Depth (cm) Diameter (cm)  Height (cm)  Weight (kg)  \
# 0  ...    33621        NaN           NaN        104.8          NaN
# 1  ...    34854        NaN           NaN         33.8          NaN
# 2  ...    35209        NaN           NaN         60.3          NaN
# 3  ...    36613        NaN           NaN        215.9          NaN
# 4  ...    37674        NaN           NaN         50.8          NaN
#
#    Width (cm)  DateYear OilPainting  Area (cm^2)  Duration (days)
# 0        74.6      1935        True      7818.08          32262.0
# 1        33.3      1929        True      1125.54          20035.0
# 2        36.8      1927        True      2219.04          21492.0
# 3        78.7      1919        True     16991.33          25250.0
# 4        54.0      1925       False      2743.20          31114.0
#
# [5 rows x 23 columns]

# %% [markdown]
# ### 1.6.5 groupby and Aggregation
#
# See slides for example.
# > This might be needed after merge sometimes.

# %% [markdown]
# ## 1.7. Data Merging

# %% [markdown]
# ### 1.7.1. Load the multiple datasets
#
# We have prepared the data from the MoMA dataset for this workshop. We will import those datasets into our notebook to use them for data analysis.
#
# Datasets can be stored in several types of files, including .csv, .json, .txt, .xls, .xlsx, and more. Here we will import a .csv file and a .json file.
#
# Preview the CSV file
# Preview the EXCEL file
# Preview the JSON file
#
# Use this link for File 1: https://raw.githubusercontent.com/ncsu-libraries-data-vis/teaching-datasets/main/moma_data/moma_paintings.csv
#
# For File 2: https://raw.githubusercontent.com/ncsu-libraries-data-vis/teaching-datasets/main/moma_data/moma_photographs.xlsx
#
# For file 3: https://raw.githubusercontent.com/ncsu-libraries-data-vis/teaching-datasets/main/moma_data/moma_sculptures.json

# %%
# load file 3 sculptures
sculptures = pd.read_json('https://raw.githubusercontent.com/ncsu-libraries-data-vis/teaching-datasets/main/moma_data/moma_sculptures.json')
sculptures.head()
# Out:
# <ipython-input-45-5d64f99e7a0d>:2: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   sculptures = pd.read_json('https://raw.githubusercontent.com/ncsu-libraries-data-vis/teaching-datasets/main/moma_data/moma_sculptures.json')
# <ipython-input-45-5d64f99e7a0d>:2: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   sculptures = pd.read_json('https://raw.githubusercontent.com/ncsu-libraries-data-vis/teaching-datasets/main/moma_data/moma_sculptures.json')
# <ipython-input-45-5d64f99e7a0d>:2: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   sculptures = pd.read_json('https://raw.githubusercontent.com/ncsu-libraries-data-vis/teaching-datasets/main/moma_data/moma_sculptures.json')
#                                                    Title           Artist  \
# 73418                     Surface with Vibrating Texture  Getulio Alviani
# 73474  IN RELATION TO AN INCREASE IN QUANTITY REGARDL...  Lawrence Weiner
# 73564                               3 Standard Stoppages   Marcel Duchamp
# 73567  To Be Looked at (from the Other Side of the Gl...   Marcel Duchamp
# 73733                                          Revolving  Kurt Schwitters
#
#        ConstituentID               Date  \
# 73418          137.0               1964
# 73474         6288.0            1973-74
# 73564         1634.0      Paris 1913-14
# 73567         1634.0  Buenos Aires 1918
# 73733         5293.0               1919
#
#                                                   Medium  \
# 73418                          Brushed aluminum on board
# 73474               LANGUAGE + THE MATERIALS REFERRED TO
# 73564  Wood box 11 1/8 x 50 7/8 x 9" (28.2 x 129.2 x ...
# 73567  Oil, silver leaf, lead wire, and magnifying le...
# 73733  Wood, metal, cord, cardboard, wool, wire, leat...
#
#                            Dimensions                     CreditLine  \
# 73418   33 x 32 3/4" (83.6 x 83.2 cm)  Larry Aldrich Foundation Fund
# 73474             Dimensions variable              Given anonymously
# 73564                            None    Katherine S. Dreier Bequest
# 73567      Overall 22" (55.8 cm) high    Katherine S. Dreier Bequest
# 73733  48 3/8 x 35" (122.7 x 88.7 cm)        Advisory Committee Fund
#
#       AccessionNumber Classification            Department  ...  \
# 73418        105.1965      Sculpture  Painting & Sculpture  ...
# 73474        117.1975      Sculpture  Painting & Sculpture  ...
# 73564    149.1953.a-i      Sculpture  Painting & Sculpture  ...
# 73567        150.1953      Sculpture  Painting & Sculpture  ...
# 73733        231.1968      Sculpture  Painting & Sculpture  ...
#
#                                             ThumbnailURL Circumference (cm)  \
# 73418  http://www.moma.org/media/W1siZiIsIjIwODIwOCJd...                NaN
# 73474  http://www.moma.org/media/W1siZiIsIjMxODk1MSJd...                NaN
# 73564  http://www.moma.org/media/W1siZiIsIjEzODY0NSJd...                NaN
# 73567  http://www.moma.org/media/W1siZiIsIjI0MzI3MyJd...                NaN
# 73733  http://www.moma.org/media/W1siZiIsIjEyMjc3MCJd...                NaN
#
#        Depth (cm) Diameter (cm) Height (cm)  Length (cm)  Weight (kg)  \
# 73418         NaN           NaN        83.6          NaN          NaN
# 73474         NaN           NaN         NaN          NaN          NaN
# 73564         NaN           NaN        13.3          NaN          NaN
# 73567         NaN           NaN        49.5          NaN          NaN
# 73733         NaN           NaN       122.7          NaN          NaN
#
#        Width (cm)  Seat Height (cm)  Duration (sec.)
# 73418        83.2               NaN              NaN
# 73474         NaN               NaN              NaN
# 73564       120.0               NaN              NaN
# 73567        39.7               NaN              NaN
# 73733        88.7               NaN              NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# #### Get to know your data

# %%
# shape

# columns

# index

# inspect columns for missing data

# identify categorical columns

# make categorical categorical

# make numbers consistent

# handle in missing data

# %% [markdown]
# ### 1.7.2. Identify columns that are common
#
# Two ways to merge:
#
# 1. If all columns are same - long merge,
# 2. if one or more columns are similar - more checks needed
#
# We will look at only case 1 today.

# %% [markdown]
# #### 1.7.2.1 Long merge
#  We want to make sure the columns are exactly the same - do we have same columns?
#
#  The cleaned dataframes of each dataset is merged

# %%
# Identify the columns that does not match
sculptures.head()
# Out:
#                                                    Title           Artist  \
# 73418                     Surface with Vibrating Texture  Getulio Alviani
# 73474  IN RELATION TO AN INCREASE IN QUANTITY REGARDL...  Lawrence Weiner
# 73564                               3 Standard Stoppages   Marcel Duchamp
# 73567  To Be Looked at (from the Other Side of the Gl...   Marcel Duchamp
# 73733                                          Revolving  Kurt Schwitters
#
#        ConstituentID               Date  \
# 73418          137.0               1964
# 73474         6288.0            1973-74
# 73564         1634.0      Paris 1913-14
# 73567         1634.0  Buenos Aires 1918
# 73733         5293.0               1919
#
#                                                   Medium  \
# 73418                          Brushed aluminum on board
# 73474               LANGUAGE + THE MATERIALS REFERRED TO
# 73564  Wood box 11 1/8 x 50 7/8 x 9" (28.2 x 129.2 x ...
# 73567  Oil, silver leaf, lead wire, and magnifying le...
# 73733  Wood, metal, cord, cardboard, wool, wire, leat...
#
#                            Dimensions                     CreditLine  \
# 73418   33 x 32 3/4" (83.6 x 83.2 cm)  Larry Aldrich Foundation Fund
# 73474             Dimensions variable              Given anonymously
# 73564                            None    Katherine S. Dreier Bequest
# 73567      Overall 22" (55.8 cm) high    Katherine S. Dreier Bequest
# 73733  48 3/8 x 35" (122.7 x 88.7 cm)        Advisory Committee Fund
#
#       AccessionNumber Classification            Department  ...  \
# 73418        105.1965      Sculpture  Painting & Sculpture  ...
# 73474        117.1975      Sculpture  Painting & Sculpture  ...
# 73564    149.1953.a-i      Sculpture  Painting & Sculpture  ...
# 73567        150.1953      Sculpture  Painting & Sculpture  ...
# 73733        231.1968      Sculpture  Painting & Sculpture  ...
#
#                                             ThumbnailURL Circumference (cm)  \
# 73418  http://www.moma.org/media/W1siZiIsIjIwODIwOCJd...                NaN
# 73474  http://www.moma.org/media/W1siZiIsIjMxODk1MSJd...                NaN
# 73564  http://www.moma.org/media/W1siZiIsIjEzODY0NSJd...                NaN
# 73567  http://www.moma.org/media/W1siZiIsIjI0MzI3MyJd...                NaN
# 73733  http://www.moma.org/media/W1siZiIsIjEyMjc3MCJd...                NaN
#
#        Depth (cm) Diameter (cm) Height (cm)  Length (cm)  Weight (kg)  \
# 73418         NaN           NaN        83.6          NaN          NaN
# 73474         NaN           NaN         NaN          NaN          NaN
# 73564         NaN           NaN        13.3          NaN          NaN
# 73567         NaN           NaN        49.5          NaN          NaN
# 73733         NaN           NaN       122.7          NaN          NaN
#
#        Width (cm)  Seat Height (cm)  Duration (sec.)
# 73418        83.2               NaN              NaN
# 73474         NaN               NaN              NaN
# 73564       120.0               NaN              NaN
# 73567        39.7               NaN              NaN
# 73733        88.7               NaN              NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# ##### 1.7.2.1.1 Reset DataFrame index labels
#
# The JSON file of sculpture artworks we imported does not include the column `Index`. Instead, these values are used as the index labels. We want this dataset to match the format of our paintings and photographs datasets, so we first need to reset the index of the `sculptures` dataset using the DataFrame method `reset_index()`.

# %%
# Reset the sculptures DataFrame index
sculptures_reset = sculptures.reset_index()


# Print out the resulting dataset
sculptures_reset.head()
# Out:
#    index                                              Title           Artist  \
# 0  73418                     Surface with Vibrating Texture  Getulio Alviani
# 1  73474  IN RELATION TO AN INCREASE IN QUANTITY REGARDL...  Lawrence Weiner
# 2  73564                               3 Standard Stoppages   Marcel Duchamp
# 3  73567  To Be Looked at (from the Other Side of the Gl...   Marcel Duchamp
# 4  73733                                          Revolving  Kurt Schwitters
#
#    ConstituentID               Date  \
# 0          137.0               1964
# 1         6288.0            1973-74
# 2         1634.0      Paris 1913-14
# 3         1634.0  Buenos Aires 1918
# 4         5293.0               1919
#
#                                               Medium  \
# 0                          Brushed aluminum on board
# 1               LANGUAGE + THE MATERIALS REFERRED TO
# 2  Wood box 11 1/8 x 50 7/8 x 9" (28.2 x 129.2 x ...
# 3  Oil, silver leaf, lead wire, and magnifying le...
# 4  Wood, metal, cord, cardboard, wool, wire, leat...
#
#                        Dimensions                     CreditLine  \
# 0   33 x 32 3/4" (83.6 x 83.2 cm)  Larry Aldrich Foundation Fund
# 1             Dimensions variable              Given anonymously
# 2                            None    Katherine S. Dreier Bequest
# 3      Overall 22" (55.8 cm) high    Katherine S. Dreier Bequest
# 4  48 3/8 x 35" (122.7 x 88.7 cm)        Advisory Committee Fund
#
#   AccessionNumber Classification  ...  \
# 0        105.1965      Sculpture  ...
# 1        117.1975      Sculpture  ...
# 2    149.1953.a-i      Sculpture  ...
# 3        150.1953      Sculpture  ...
# 4        231.1968      Sculpture  ...
#
#                                         ThumbnailURL Circumference (cm)  \
# 0  http://www.moma.org/media/W1siZiIsIjIwODIwOCJd...                NaN
# 1  http://www.moma.org/media/W1siZiIsIjMxODk1MSJd...                NaN
# 2  http://www.moma.org/media/W1siZiIsIjEzODY0NSJd...                NaN
# 3  http://www.moma.org/media/W1siZiIsIjI0MzI3MyJd...                NaN
# 4  http://www.moma.org/media/W1siZiIsIjEyMjc3MCJd...                NaN
#
#   Depth (cm)  Diameter (cm) Height (cm) Length (cm)  Weight (kg)  Width (cm)  \
# 0        NaN            NaN        83.6         NaN          NaN        83.2
# 1        NaN            NaN         NaN         NaN          NaN         NaN
# 2        NaN            NaN        13.3         NaN          NaN       120.0
# 3        NaN            NaN        49.5         NaN          NaN        39.7
# 4        NaN            NaN       122.7         NaN          NaN        88.7
#
#    Seat Height (cm)  Duration (sec.)
# 0               NaN              NaN
# 1               NaN              NaN
# 2               NaN              NaN
# 3               NaN              NaN
# 4               NaN              NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# Renaming column labels
# When we reset our index a new column with the label index was created. Let's change the name of this column to Index (with an uppercase "I") to match our other datasets using the DataFrame method rename().

# %%
# Rename the column we created to differentiate from the default index
sculptures_rename = sculptures_reset.rename(columns={'index': 'Index'})

# Print out the first five columns of the dataset
sculptures_rename
# Out:
#        Index                                              Title  \
# 0      73418                     Surface with Vibrating Texture
# 1      73474  IN RELATION TO AN INCREASE IN QUANTITY REGARDL...
# 2      73564                               3 Standard Stoppages
# 3      73567  To Be Looked at (from the Other Side of the Gl...
# 4      73733                                          Revolving
# ...      ...                                                ...
# 1705  136495                                 Disease Thrower #5
# 1706  136496                                     Circle Serpent
# 1707  136526                                       Candle Piece
# 1708  136539  Unfinished Construction. Posthumous Homage to ...
# 1709  136546                                 To Die Upon A Kiss
#
#                    Artist  ConstituentID               Date  \
# 0         Getulio Alviani          137.0               1964
# 1         Lawrence Weiner         6288.0            1973-74
# 2          Marcel Duchamp         1634.0      Paris 1913-14
# 3          Marcel Duchamp         1634.0  Buenos Aires 1918
# 4         Kurt Schwitters         5293.0               1919
# ...                   ...            ...                ...
# 1705  Guadalupe Maravilla       131948.0               2019
# 1706  Guadalupe Maravilla       131948.0               2019
# 1707        Richard Serra         5349.0               1967
# 1708      Mathias Goeritz         2203.0            c. 1953
# 1709          Fred Wilson        26607.0               2011
#
#                                                  Medium  \
# 0                             Brushed aluminum on board
# 1                  LANGUAGE + THE MATERIALS REFERRED TO
# 2     Wood box 11 1/8 x 50 7/8 x 9" (28.2 x 129.2 x ...
# 3     Oil, silver leaf, lead wire, and magnifying le...
# 4     Wood, metal, cord, cardboard, wool, wire, leat...
# ...                                                 ...
# 1705  Glass, steel, wood, cotton, plastic, loofah, p...
# 1706                                      Maguey leaves
# 1707                                    Wood and candle
# 1708                                       Painted wood
# 1709                                              Glass
#
#                                           Dimensions  \
# 0                      33 x 32 3/4" (83.6 x 83.2 cm)
# 1                                Dimensions variable
# 2                                               None
# 3                         Overall 22" (55.8 cm) high
# 4                     48 3/8 x 35" (122.7 x 88.7 cm)
# ...                                              ...
# 1705        91 × 55 × 45" (231.1 × 139.7 × 114.3 cm)
# 1706                             Dimensions variable
# 1707  11 13/16 × 144 1/8 × 3 9/16" (30 × 366 × 9 cm)
# 1708   36 5/8 × 14 15/16 × 28 3/4" (93 × 38 × 73 cm)
# 1709    70 × 68 1/2 × 68 1/2" (177.8 × 174 × 174 cm)
#
#                                        CreditLine AccessionNumber  \
# 0                   Larry Aldrich Foundation Fund        105.1965
# 1                               Given anonymously        117.1975
# 2                     Katherine S. Dreier Bequest    149.1953.a-i
# 3                     Katherine S. Dreier Bequest        150.1953
# 4                         Advisory Committee Fund        231.1968
# ...                                           ...             ...
# 1705            Fund for the Twenty-First Century        703.2019
# 1706            Fund for the Twenty-First Century        704.2019
# 1707                        Gift of Peter Freeman    707.2019.a-b
# 1708                                         None         TR16416
# 1709  Gift of Agnes Gund in honor of Maria Martin        710.2019
#
#      Classification  ...                                       ThumbnailURL  \
# 0         Sculpture  ...  http://www.moma.org/media/W1siZiIsIjIwODIwOCJd...
# 1         Sculpture  ...  http://www.moma.org/media/W1siZiIsIjMxODk1MSJd...
# 2         Sculpture  ...  http://www.moma.org/media/W1siZiIsIjEzODY0NSJd...
# 3         Sculpture  ...  http://www.moma.org/media/W1siZiIsIjI0MzI3MyJd...
# 4         Sculpture  ...  http://www.moma.org/media/W1siZiIsIjEyMjc3MCJd...
# ...             ...  ...                                                ...
# 1705      Sculpture  ...  http://www.moma.org/media/W1siZiIsIjQ3NTM0NiJd...
# 1706      Sculpture  ...  http://www.moma.org/media/W1siZiIsIjQ3NTM0OSJd...
# 1707      Sculpture  ...  http://www.moma.org/media/W1siZiIsIjQ3NTM1NSJd...
# 1708      Sculpture  ...                                               None
# 1709      Sculpture  ...  http://www.moma.org/media/W1siZiIsIjQ3NjU4NCJd...
#
#      Circumference (cm)  Depth (cm)  Diameter (cm) Height (cm) Length (cm)  \
# 0                   NaN         NaN            NaN   83.600000         NaN
# 1                   NaN         NaN            NaN         NaN         NaN
# 2                   NaN         NaN            NaN   13.300000         NaN
# 3                   NaN         NaN            NaN   49.500000         NaN
# 4                   NaN         NaN            NaN  122.700000         NaN
# ...                 ...         ...            ...         ...         ...
# 1705                NaN  114.300229            NaN  231.140462         NaN
# 1706                NaN         NaN            NaN         NaN         NaN
# 1707                NaN    9.000000            NaN   30.000000         NaN
# 1708                NaN   73.000000            NaN   93.000000         NaN
# 1709                NaN  174.000000            NaN  177.800000         NaN
#
#       Weight (kg)  Width (cm)  Seat Height (cm)  Duration (sec.)
# 0             NaN   83.200000               NaN              NaN
# 1             NaN         NaN               NaN              NaN
# 2             NaN  120.000000               NaN              NaN
# 3             NaN   39.700000               NaN              NaN
# 4             NaN   88.700000               NaN              NaN
# ...           ...         ...               ...              ...
# 1705          NaN  139.700279               NaN              NaN
# 1706          NaN         NaN               NaN              NaN
# 1707          NaN  366.000000               NaN              NaN
# 1708          NaN   38.000000               NaN              NaN
# 1709          NaN  174.000000               NaN              NaN
#
# [1710 rows x 25 columns]

# %% [markdown]
# ##### 1.7.2.1.2 Concatenate DataFrames
# We want to be able to work with all of the data we have imported at once, so we need to pull all two DataFrames into one DataFrame. They all have the same column format now, so we can concatenate them based on column name and order (similar to adding them together, one on top of another) using the pandas method concat().
#
# We also need to consider the current index labels for each dataset. We will create a new zero-based integer index label for the concatenated dataset by passing the keyword argument ignore_index=True into the concat() method.
#
# Ensure you are concatenating the cleaned dataframes.

# %%
# Concatenate all the datasets into one
moma_art = pd.concat([paintings, sculptures_rename], ignore_index=True)


# Print the shape (number of rows and columns) of the full DataFrame
moma_art.shape
# Out:
# (4060, 29)

# %% [markdown]
# ### 1.7.2.2 Broad Merge
#
# In cases where borad merge based on common column is required.

# %%
# consider the file 2: For File 2:
# with URL: https://raw.githubusercontent.com/ncsu-libraries-data-vis/teaching-datasets/main/moma_data/moma_photographs.xlsx
photos = pd.read_excel('https://raw.githubusercontent.com/ncsu-libraries-data-vis/teaching-datasets/main/moma_data/moma_photographs.xlsx')
photos.head()

# import the file to pandas
# Out:
#    Index                                   Title        Artist  ConstituentID  \
# 0  30700             Untitled from VVV Portfolio    David Hare         2504.0
# 1  36358  Tuileries Sanglier / d'apres l'antique  Eugène Atget          229.0
# 2  36359                         Sapin (Trianon)  Eugène Atget          229.0
# 3  36360             Versailles, vase par Ballin  Eugène Atget          229.0
# 4  36361                                 Facteur  Eugène Atget          229.0
#
#                       Date                                             Medium  \
# 0  c. 1941, published 1943  Gelatin silver print mounted on paper from a p...
# 1                     1911                               Albumen silver print
# 2                  1910-14                               Albumen silver print
# 3                     1902                         Matte albumen silver print
# 4                1899-1900            Gelatin silver printing-out-paper print
#
#                                           Dimensions  \
# 0  composition: 12 x 9 3/4" (30.5 x 24.8 cm); she...
# 1                   8 11/16 × 6 9/16" (22 × 16.7 cm)
# 2            Approx. 7 1/8 × 8 5/8" (18.1 × 21.9 cm)
# 3            Approx. 8 9/16 × 7 1/16" (21.8 × 18 cm)
# 4           Approx. 8 11/16 × 6 9/16" (22 × 16.7 cm)
#
#                                           CreditLine AccessionNumber  \
# 0                      The Louis E. Stern Collection     1113.1964.6
# 1  Abbott-Levy Collection. Partial gift of Shirle...        1.1969.1
# 2  Abbott-Levy Collection. Partial gift of Shirle...       1.1969.10
# 3  Abbott-Levy Collection. Partial gift of Shirle...      1.1969.100
# 4  Abbott-Levy Collection. Partial gift of Shirle...     1.1969.1000
#
#   Classification  ...                                       ThumbnailURL  \
# 0     Photograph  ...  http://www.moma.org/media/W1siZiIsIjM0NTUzOCJd...
# 1     Photograph  ...  http://www.moma.org/media/W1siZiIsIjMwMTMwNCJd...
# 2     Photograph  ...  http://www.moma.org/media/W1siZiIsIjMxODEwMSJd...
# 3     Photograph  ...  http://www.moma.org/media/W1siZiIsIjMxODEwMiJd...
# 4     Photograph  ...  http://www.moma.org/media/W1siZiIsIjI4NjE4MiJd...
#
#   Circumference (cm) Depth (cm)  Diameter (cm) Height (cm) Length (cm)  \
# 0                NaN        NaN            NaN        30.5         NaN
# 1                NaN        NaN            NaN         NaN         NaN
# 2                NaN        NaN            NaN         NaN         NaN
# 3                NaN        NaN            NaN         NaN         NaN
# 4                NaN        NaN            NaN         NaN         NaN
#
#    Weight (kg)  Width (cm)  Seat Height (cm)  Duration (sec.)
# 0          NaN        24.8               NaN              NaN
# 1          NaN         NaN               NaN              NaN
# 2          NaN         NaN               NaN              NaN
# 3          NaN         NaN               NaN              NaN
# 4          NaN         NaN               NaN              NaN
#
# [5 rows x 25 columns]

# %%
# get to know and clean data

# %%
# Identify the column you want to merge on


# How do you identify?
# the format and values should be consistent across the datasets

# you could merge and see if it works

# or you can find values that are common

import pandas as pd

common_ids = list(set(paintings["ConstituentID"]) & set(photos["ConstituentID"]))
print(len(common_ids))

common_artists = list(set(paintings["Artist"]) & set(photos["Artist"]))
print(common_artists)
# Out:
# 55
# ['Friedrich Vordemberge-Gildewart', 'Nicholas Africano', 'Ben Vautier', 'Robert Rauschenberg', 'Richard Artschwager', 'Allan McCollum', 'David Hockney', 'Aleksandr Rodchenko', 'Herbert Bayer', 'Theodore Lux Feininger', 'David Wojnarowicz', 'Alexander Liberman', 'Yayoi Kusama', 'A. E. Gallatin', 'Ger van Elk', 'James Edward Davis', 'George Maciunas', 'Geraldo de Barros', 'Sherrie Levine', 'Ben Shahn', 'Lyonel Feininger', 'Jim Dine', 'Yoko Ono', 'Raoul Ubac', 'Jan Dibbets', 'Sigmar Polke', 'Douglas Blau', 'Richard Pousette-Dart', 'Chuck Close', 'Nam June Paik', 'Allen Ruppersberg', 'Charles Sheeler', 'Man Ray (Emmanuel Radnitzky)', 'László Moholy-Nagy', 'Romare Bearden', 'Isa Genzken', 'Otto Piene', 'Marcel Broodthaers', 'Richard Prince', 'Francis Alÿs', nan, 'Bruce Nauman', 'Gabriel Orozco', 'Jacques Charlier', 'Josef Albers', 'Sophie Calle', 'Felix Gonzalez-Torres', 'Howardena Pindell', 'John Baldessari', 'Hermann Nitsch', 'Andy Warhol', 'El Lissitzky', 'Robert Gober', 'Günther Förg', 'Geta Brătescu', 'Arman']

# %% [markdown]
# If the common values exist merge it or else look for other columns

# %% [markdown]
# ### Join DataFrames on shared column values
#
# Our dataset includes a column of unique artist IDs (`ConstituentID`) that identify a specific artist.

# %% [markdown]
# ![Left join visual example](https://github.com/ncsu-libraries-data-vis/python-open-labs/blob/main/Open_Lab_2_working_with_multiple_datasets_in_pandas/left-join.png?raw=1)
#
# We will use a "left" join to merge columns from the `photos` DataFrame into the `moma_art` DataFrame based on matching values in each DataFrame's `ConstituentID` column.
#
# Read more about [joins](https://www.geeksforgeeks.org/different-types-of-joins-in-pandas/).

# %%
# Create a new DataFrame from a "left" join of the full artworks DataFrame
# and the artists DataFrame base on the shared column "ConstituentID"
moma_art_photos = paintings.merge(photos, how='left', on='ConstituentID')

# Print out the new merged dataset
moma_art_photos.head()
# Out:
#    Index_x                     Title_x       Artist_x  ConstituentID  \
# 0    32095          Rope and People, I      Joan Miró           4016
# 1    33167         Fire in the Evening      Paul Klee           3130
# 2    33424  Portrait of an Equilibrist      Paul Klee           3130
# 3    34481                      Guitar  Pablo Picasso           4609
# 4    35396                 Grandmother    Arthur Dove           1602
#
#                       Date_x  \
# 0  Barcelona, March 27, 1935
# 1                       1929
# 2                       1927
# 3          Paris, early 1919
# 4                       1925
#
#                                             Medium_x  \
# 0  Oil on cardboard mounted on wood, with coil of...
# 1                                   Oil on cardboard
# 2  Oil and collage on cardboard over wood with pa...
# 3           Oil, charcoal and pinned paper on canvas
# 4  Shingles, needlepoint, page from Concordance, ...
#
#                          Dimensions_x  \
# 0  41 1/4 x 29 3/8" (104.8 x 74.6 cm)
# 1   13 3/8 x 13 1/4" (33.8 x 33.3 cm)
# 2     24 7/8 x 15 3/4" (63.2 x 40 cm)
# 3         7' 1" x 31" (216 x 78.8 cm)
# 4       20 x 21 1/4" (50.8 x 54.0 cm)
#
#                               CreditLine_x AccessionNumber_x Classification_x  \
# 0       Gift of the Pierre Matisse Gallery           71.1936         Painting
# 1  Mr. and Mrs. Joachim Jean Aberbach Fund          153.1970         Painting
# 2               Mrs. Simon Guggenheim Fund          195.1966         Painting
# 3               Gift of A. Conger Goodyear          384.1955         Painting
# 4  Gift of Philip L. Goodwin (by exchange)          636.1939         Painting
#
#    ... ThumbnailURL Circumference (cm) Depth (cm)_y  Diameter (cm)_y  \
# 0  ...          NaN                NaN          NaN              NaN
# 1  ...          NaN                NaN          NaN              NaN
# 2  ...          NaN                NaN          NaN              NaN
# 3  ...          NaN                NaN          NaN              NaN
# 4  ...          NaN                NaN          NaN              NaN
#
#    Height (cm)_y  Length (cm)  Weight (kg)_y Width (cm)_y  Seat Height (cm)  \
# 0            NaN          NaN            NaN          NaN               NaN
# 1            NaN          NaN            NaN          NaN               NaN
# 2            NaN          NaN            NaN          NaN               NaN
# 3            NaN          NaN            NaN          NaN               NaN
# 4            NaN          NaN            NaN          NaN               NaN
#
#    Duration (sec.)
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 47 columns]

# %%
moma_art_photos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5849 entries, 0 to 5848
# Data columns (total 47 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Index_x             5849 non-null   int64
#  1   Title_x             5849 non-null   object
#  2   Artist_x            5666 non-null   object
#  3   ConstituentID       5666 non-null   Int64
#  4   Date_x              5550 non-null   object
#  5   Medium_x            5666 non-null   object
#  6   Dimensions_x        5642 non-null   object
#  7   CreditLine_x        5842 non-null   object
#  8   AccessionNumber_x   5849 non-null   object
#  9   Classification_x    5849 non-null   category
#  10  Department_x        5849 non-null   category
#  11  DateAcquired_x      5777 non-null   datetime64[ns]
#  12  Cataloged_x         5849 non-null   category
#  13  ObjectID_x          5849 non-null   int64
#  14  Depth (cm)_x        2236 non-null   float64
#  15  Diameter (cm)_x     12 non-null     float64
#  16  Height (cm)_x       5849 non-null   float64
#  17  Weight (kg)_x       3 non-null      category
#  18  Width (cm)_x        5849 non-null   float64
#  19  DateYear            5550 non-null   Int64
#  20  OilPainting         5666 non-null   category
#  21  Area (cm^2)         5849 non-null   float64
#  22  Duration (days)     5777 non-null   float64
#  23  Index_y             3683 non-null   float64
#  24  Title_y             3656 non-null   object
#  25  Artist_y            3500 non-null   object
#  26  Date_y              3605 non-null   object
#  27  Medium_y            3629 non-null   object
#  28  Dimensions_y        3408 non-null   object
#  29  CreditLine_y        3681 non-null   object
#  30  AccessionNumber_y   3683 non-null   object
#  31  Classification_y    3683 non-null   object
#  32  Department_y        3683 non-null   object
#  33  DateAcquired_y      2957 non-null   object
#  34  Cataloged_y         3683 non-null   object
#  35  ObjectID_y          3683 non-null   float64
#  36  URL                 1741 non-null   object
#  37  ThumbnailURL        1727 non-null   object
#  38  Circumference (cm)  0 non-null      float64
#  39  Depth (cm)_y        423 non-null    float64
#  40  Diameter (cm)_y     0 non-null      float64
#  41  Height (cm)_y       3509 non-null   float64
#  42  Length (cm)         0 non-null      float64
#  43  Weight (kg)_y       0 non-null      float64
#  44  Width (cm)_y        3509 non-null   float64
#  45  Seat Height (cm)    0 non-null      float64
#  46  Duration (sec.)     0 non-null      float64
# dtypes: Int64(2), category(5), datetime64[ns](1), float64(17), int64(2), object(20)
# memory usage: 1.9+ MB

# %% [markdown]
# There are also other joins, like inner join that only joins

# %% [markdown]
# ## Try it yourself
#
# For these exercises you will be using a dataset that consists of MoMA artworks classified as photographs and each photograph's associated artist information. This dataset has the same columns and column names as the original paintings dataset from the guided activity.
#
# Before starting the exercises you will need to load the new dataset as DataFrames. It is available as a CSV file and the URL to the file is provided in the variable below.

# %%
# URLs to the photographs dataset
photos_file_url = 'https://raw.githubusercontent.com/ncsu-libraries-data-vis/teaching-datasets/main/moma_data/moma_photographs_full.csv'

# Import the photographs dataset as a DataFrame

# %% [markdown]
# ### Exercise 1: Rename column values
#
# In the photographs dataset, replace the values in the column `Cataloged`. Replace all occurrences of the value `Y` with the value `Yes` and all occurrences of the value `N` with the value `No`. Overwrite the existing values with the new values.

# %%
# Replace the values "Y" and "N" in the "Cataloged" column with "Yes" and "No"

# %% [markdown]
# ### Exercise 2: Create a new column using an expression
#
# Create a new column, `Aspect`, that contains the aspect ratio (width / height) of a photograph using the values in the `Width (cm)` and `Height (cm)` columns.

# %%
# Create a new column named "Aspect" that contains the aspect ratio of a
# photograph based on the values in columns "Width (cm)" and "Height (cm)"

# %% [markdown]
# ### Exercise 3: Create a new column using apply
#
# Use the values in the column `BeginDate` to create a new column, `CenturyBorn`, in the photos DataFrame that indicates the century in which an artist was born using a function that returns:
# - `18th` if the artist was born between 1700-1799,
# - `19th` if the artist was born between 1800-1899,
# - `20th` if the artist was born between 1900-1999,
# - `21st` if the artist was born between 2000-present, and
# - `unknown` otherwise.
#
# The `BeginDate` column contains the year in which an artist was born. Unknown artist birth years are identified with the value `0`. The function `century_born()` has been provided for you to use with the apply method, but you can create your own for extra practice.

# %%
# Return the century in which an artist was born given their birth year
def century_born(year):
    if year > 1999:
        return '21st'
    elif year > 1899:
        return '20th'
    elif year > 1799:
        return '19th'
    elif year > 1699:
        return '18th'
    return 'unknown'

# Create a new column named "CenturyBorn" that contains the century in which an
# artist was born using data from the column "BeginDate" and the function
# century_born

# %% [markdown]
# ### Exercise 4: Remove missing values
#
# We are only interested in artworks that have a defined width and height. Use the column `Aspect` to remove any rows from the dataset that do not have a defined aspect ratio (in other words, values that are `NaN`).

# %%
# Remove rows from the dataset that have an "NaN" value in the "Aspect" column

# %% [markdown]
# ### Exercise 5: Use a string method to normalize data
#
# Normalize the values in the column `Gender` by applying the string method `title()` to convert all strings to title case (for example, convert `male` to `Male` and `female` to `Female`). Print out the unique values of this column after performing the operation to ensure only three values are present (`Male`, `Female`, and `nan`).

# %%
# Normalize the string values in the "Gender" column to title case (each word
# beginning with a capital letter)

# %% [markdown]
# ### Exercise 6: Convert string data to Datetime
#
# Convert the string data contained in the column `DateAcquired` to Datetime data type. Reassign the new Datetime values to the existing `DateAcquired` column and then use this column to filter the DataFrame for items acquired in or after the year 2020.

# %%
# Convert the string data in the column "DateAcquired" to a Datetime data type


# Use the updated column to filter the DataFrame to photos acquired in or after
# the year 2020

# %% [markdown]
# # Learning resources
#
# - [Python Data Science Handbook](https://jakevdp.github.io/PythonDataScienceHandbook/index.html) - a free, online version of Jake VanderPlas' introduction to data science with Python, includes a chapter on data manipulation with pandas.
# - [Python Programming for Data Science](https://www.tomasbeuzen.com/python-programming-for-data-science/README.html) - a website providing a great overview of conducting data science with Python including pandas.
# - [Real Python](https://realpython.com/) contains a lot of different tutorials at different levels
# - [LinkedIn Learning](https://www.lynda.com/Python-training-tutorials/415-0.html) is free with NC State accounts and contains several video series for learning Python
# - [Dataquest](https://www.dataquest.io/) is a free then paid series of courses with an emphasis on data science
#
# ### Finding help with pandas
#
# The [Pandas website](https://pandas.pydata.org/) and [online documentation](http://pandas.pydata.org/pandas-docs/stable/) are useful resources, and of course the indispensible [Stack Overflow has a "pandas" tag](https://stackoverflow.com/questions/tagged/pandas).  There is also a (much younger, much smaller) [sister site dedicated to Data Science questions that has a "pandas" tag](https://datascience.stackexchange.com/questions/tagged/pandas) too.

# %% [markdown]
# # Credits
#
# This workshop was created by Aditi Mallavarapu, Claire Cahoon and Walt Gurley, adapted from previous workshop materials by Scott Bailey and Simon Wiles, of Stanford Libraries.
